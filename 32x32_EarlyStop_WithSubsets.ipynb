# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
import torch.nn.functional as F


from torch.utils.data import Dataset
from PIL import Image
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, image_paths, label_paths):
        self.image_paths = image_paths
        self.label_paths = label_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load the image using PIL
        with Image.open(self.image_paths[idx]) as img:
            np_image = np.array(img, dtype=np.float32)

        # Normalize the image
        normalized_image = np_image / 65535.0  # Assuming 16-bit images

        # Load and process the label data using PIL
        with Image.open(self.label_paths[idx]) as label_img:
            label_array = np.array(label_img, dtype=np.float32)

        grayscale_to_class_mapping = {0: 0, 128: 1, 255: 2} # Maps gray-levels to class

        # Map grayscale values to class labels
        mapped_labels = np.copy(label_array)
        for grayscale_value, class_id in grayscale_to_class_mapping.items():
            mapped_labels[label_array == grayscale_value] = class_id

        # Convert to PyTorch tensors
        image_tensor = torch.from_numpy(normalized_image).unsqueeze(0) # Add channel dimension
        label_tensor = torch.from_numpy(mapped_labels).long() # Ensure label tensor is long type

        return image_tensor, label_tensor

# %%
### Label images ###
# white class - 255 nickel
# gray class - 128 ysz
# black class - 0 pores

class UNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()

        # Define a helper function for creating a block
        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
                nn.Dropout(p=0.1)
            )

        # Encoder
        self.e11 = conv_block(1, 64)
        self.e12 = conv_block(64, 64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e21 = conv_block(64, 128)
        self.e22 = conv_block(128, 128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e31 = conv_block(128, 256)
        self.e32 = conv_block(256, 256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e41 = conv_block(256, 512)
        self.e42 = conv_block(512, 512)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e51 = conv_block(512, 1024)
        self.e52 = conv_block(1024, 1024)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.d11 = conv_block(1024, 512)
        self.d12 = conv_block(512, 512)

        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.d21 = conv_block(512, 256)
        self.d22 = conv_block(256, 256)

        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.d31 = conv_block(256, 128)
        self.d32 = conv_block(128, 128)

        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.d41 = conv_block(128, 64)
        self.d42 = conv_block(64, 64)

        # Output layer
        self.outconv = nn.Conv2d(64, n_class, kernel_size=1)

    def forward(self, x):
        # Encoder
        xe11 = self.e11(x)
        xe12 = self.e12(xe11)
        xp1 = self.pool1(xe12)

        xe21 = self.e21(xp1)
        xe22 = self.e22(xe21)
        xp2 = self.pool2(xe22)

        xe31 = self.e31(xp2)
        xe32 = self.e32(xe31)
        xp3 = self.pool3(xe32)

        xe41 = self.e41(xp3)
        xe42 = self.e42(xe41)
        xp4 = self.pool4(xe42)

        xe51 = self.e51(xp4)
        xe52 = self.e52(xe51)

        # Decoder
        xu1 = self.upconv1(xe52)
        xu11 = torch.cat([xu1, xe42], dim=1)
        xd11 = self.d11(xu11)
        xd12 = self.d12(xd11)

        xu2 = self.upconv2(xd12)
        xu22 = torch.cat([xu2, xe32], dim=1)
        xd21 = self.d21(xu22)
        xd22 = self.d22(xd21)

        xu3 = self.upconv3(xd22)
        xu33 = torch.cat([xu3, xe22], dim=1)
        xd31 = self.d31(xu33)
        xd32 = self.d32(xd31)

        xu4 = self.upconv4(xd32)
        xu44 = torch.cat([xu4, xe12], dim=1)
        xd41 = self.d41(xu44)
        xd42 = self.d42(xd41)

        # Output layer
        out = self.outconv(xd42)

        return out

# %%
from torch.utils.data import DataLoader, random_split
from torch import optim
import torch
import os
import matplotlib.pyplot as plt

def dice_coefficient(predicted, target, num_classes):
    dice_scores = []  # To store dice coefficient for each class

    # Convert predictions and targets to one-hot encoded form
    predicted_one_hot = F.one_hot(predicted, num_classes).permute(0, 3, 1, 2).float()
    target_one_hot = F.one_hot(target, num_classes).permute(0, 3, 1, 2).float()

    # Calculate Dice coefficient for each class
    for class_index in range(num_classes):
        intersection = (predicted_one_hot[:, class_index, :, :] * target_one_hot[:, class_index, :, :]).sum()
        union = predicted_one_hot[:, class_index, :, :].sum() + target_one_hot[:, class_index, :, :].sum()
        dice_score = (2 * intersection + 1e-6) / (union + 1e-6)  # Adding a small epsilon to avoid division by zero
        dice_scores.append(dice_score)

    # Average Dice score across all classes
    avg_dice_score = sum(dice_scores) / len(dice_scores)
    return avg_dice_score.item()  # Return the value as a Python scalar

def get_image_paths(data_dir, label_dir):
    data_paths = [os.path.join(data_dir, img) for img in sorted(os.listdir(data_dir))]
    label_paths = [os.path.join(label_dir, lbl) for lbl in sorted(os.listdir(label_dir))]
    return data_paths, label_paths

def create_subsets(dataset, subset_sizes):
    subsets = {}
    for size in subset_sizes:
        if size == len(dataset):
            subsets[size] = dataset  # Use the full dataset
        else:
            subset, _ = random_split(dataset, [size, len(dataset) - size])
            subsets[size] = subset
    return subsets

def plot_predictions(images, actuals, predicted):
    plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
    for i in range(len(images)):
        # Rescale the images from [0, 1] to [0, 65535]
        image = images[i].squeeze() * 65535

        # Contrast stretching the original image for visualization (directly doing 16bit to 8bit got fucked)
        vmin, vmax = image.min(), image.max()
        image = (image - vmin) / (vmax - vmin)  # Scale pixel values to 0-1 range
        image = (image * 255).to(torch.uint8).cpu().numpy()  # Scale up to 0-255 range and convert to 8-bit

        # Display the original image
        plt.subplot(1, len(images)*3, i*3+1)
        plt.imshow(image, cmap='gray')
        plt.title(f'Original Image')
        plt.axis('off')

        # Display the actual label image
        actual = actuals[i].squeeze()  # Assuming actuals is a batch of label images
        plt.subplot(1, len(images)*3, i*3+2)
        plt.imshow(actual, cmap='gray')
        plt.title(f'Actual Label')
        plt.axis('off')

        # Display the predicted label image
        pred = predicted[i].squeeze()  # Assuming predicted is a batch of label images
        plt.subplot(1, len(images)*3, i*3+3)
        plt.imshow(pred, cmap='gray')
        plt.title(f'Predicted Label')
        plt.axis('off')

    plt.show()

# %%
# Define your dataset paths
data_dir = '/content/gdrive/MyDrive/training_dataset/data_resize32/'
label_dir = '/content/gdrive/MyDrive/training_dataset/label_resize32/'

# Get image paths and create the full dataset
image_paths, label_paths = get_image_paths(data_dir, label_dir)
dataset = CustomDataset(image_paths=image_paths, label_paths=label_paths)

# Define subset sizes including the full dataset size
subset_size = [100, 250, len(dataset)]  # Add the full dataset size

# Create subsets
dataset_subsets = create_subsets(dataset, subset_size)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")

# Training configurations
learning_rate = 0.001
num_epochs = 250  # Adjust as needed

# Early stopping parameters
patience = 10  # Number of epochs to wait after last improvement
best_val_loss = float('inf')  # Initialize best validation loss as infinity
epochs_no_improve = 0  # Counter for epochs without improvement

# Loop over subsets and train the model
for size, subset in dataset_subsets.items():
    print(f"\nTraining on subset size: {size}")

    # Reset early stopping parameters for each subset
    best_val_loss = float('inf')
    epochs_no_improve = 0

    # Split the subset into training, validation, and test datasets
    train_size = int(0.70 * len(subset))
    val_size = int(0.15 * len(subset))
    test_size = len(subset) - train_size - val_size
    train_dataset, val_dataset, test_dataset = random_split(subset, [train_size, val_size, test_size])

    # DataLoader setup
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Model, loss function, and optimizer setup
    model = UNet(n_class=3).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        for batch_idx, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            labels = labels.squeeze(1).long()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item()}")

        # Validation phase
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                labels = labels.squeeze(1).long()
                loss = criterion(outputs, labels)
                val_loss += loss.item()
            val_loss /= len(val_loader)
            print(f"Validation Loss after Epoch {epoch+1}: {val_loss}")

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f"Validation Loss after Epoch {epoch+1}: {val_loss}, Epochs without improvement: {epochs_no_improve}")

        if epochs_no_improve == patience:
            print("Early stopping triggered")
            break


    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        test_loss = 0
        correct = 0
        total = 0
        dice_scores = []

        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probabilities = F.softmax(outputs, dim=1)
            _, predicted = torch.max(probabilities, 1)
            labels = labels.squeeze(1).long()

            loss = criterion(outputs, labels)
            test_loss += loss.item()
            total += labels.numel()
            correct += (predicted == labels).sum().item()

            dice_score = dice_coefficient(predicted, labels, num_classes=3)
            dice_scores.append(dice_score)

        test_loss /= len(test_loader)
        test_accuracy = 100 * correct / total
        average_dice_score = sum(dice_scores) / len(dice_scores)

        print(f"Subset size {size} - Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%, Average Dice Score: {average_dice_score:.4f}")

        # Select a few images (e.g., first 4)
        selected_images = images[:4].cpu()
        actual_labels = labels[:4].cpu()
        predicted_labels = predicted[:4].cpu()

        # Call the function
        plot_predictions(selected_images, actual_labels, predicted_labels)
# Out:
# Using cuda
#
# Training on subset size: 100
# Epoch 1/250, Batch 1/3, Loss: 1.1442991495132446
# Validation Loss after Epoch 1: 1.0919636487960815
# Validation Loss after Epoch 1: 1.0919636487960815, Epochs without improvement: 0
# Epoch 2/250, Batch 1/3, Loss: 0.6732193827629089
# Validation Loss after Epoch 2: 1.0752853155136108
# Validation Loss after Epoch 2: 1.0752853155136108, Epochs without improvement: 0
# Epoch 3/250, Batch 1/3, Loss: 0.544365406036377
# Validation Loss after Epoch 3: 1.0583754777908325
# Validation Loss after Epoch 3: 1.0583754777908325, Epochs without improvement: 0
# Epoch 4/250, Batch 1/3, Loss: 0.47826170921325684
# Validation Loss after Epoch 4: 1.1216471195220947
# Validation Loss after Epoch 4: 1.1216471195220947, Epochs without improvement: 1
# Epoch 5/250, Batch 1/3, Loss: 0.4333990812301636
# Validation Loss after Epoch 5: 1.2281949520111084
# Validation Loss after Epoch 5: 1.2281949520111084, Epochs without improvement: 2
# Epoch 6/250, Batch 1/3, Loss: 0.39294835925102234
# Validation Loss after Epoch 6: 1.3931853771209717
# Validation Loss after Epoch 6: 1.3931853771209717, Epochs without improvement: 3
# Epoch 7/250, Batch 1/3, Loss: 0.36099669337272644
# Validation Loss after Epoch 7: 1.4604991674423218
# Validation Loss after Epoch 7: 1.4604991674423218, Epochs without improvement: 4
# Epoch 8/250, Batch 1/3, Loss: 0.32858046889305115
# Validation Loss after Epoch 8: 1.462866187095642
# Validation Loss after Epoch 8: 1.462866187095642, Epochs without improvement: 5
# Epoch 9/250, Batch 1/3, Loss: 0.3097851276397705
# Validation Loss after Epoch 9: 1.3816889524459839
# Validation Loss after Epoch 9: 1.3816889524459839, Epochs without improvement: 6
# Epoch 10/250, Batch 1/3, Loss: 0.2804689109325409
# Validation Loss after Epoch 10: 1.2507771253585815
# Validation Loss after Epoch 10: 1.2507771253585815, Epochs without improvement: 7
# Epoch 11/250, Batch 1/3, Loss: 0.2652527689933777
# Validation Loss after Epoch 11: 1.0847872495651245
# Validation Loss after Epoch 11: 1.0847872495651245, Epochs without improvement: 8
# Epoch 12/250, Batch 1/3, Loss: 0.24807007610797882
# Validation Loss after Epoch 12: 0.9638242721557617
# Validation Loss after Epoch 12: 0.9638242721557617, Epochs without improvement: 0
# Epoch 13/250, Batch 1/3, Loss: 0.22628940641880035
# Validation Loss after Epoch 13: 0.8587487936019897
# Validation Loss after Epoch 13: 0.8587487936019897, Epochs without improvement: 0
# Epoch 14/250, Batch 1/3, Loss: 0.20956678688526154
# Validation Loss after Epoch 14: 0.7403547763824463
# Validation Loss after Epoch 14: 0.7403547763824463, Epochs without improvement: 0
# Epoch 15/250, Batch 1/3, Loss: 0.19432716071605682
# Validation Loss after Epoch 15: 0.6397973299026489
# Validation Loss after Epoch 15: 0.6397973299026489, Epochs without improvement: 0
# Epoch 16/250, Batch 1/3, Loss: 0.1860925257205963
# Validation Loss after Epoch 16: 0.5343289971351624
# Validation Loss after Epoch 16: 0.5343289971351624, Epochs without improvement: 0
# Epoch 17/250, Batch 1/3, Loss: 0.16915740072727203
# Validation Loss after Epoch 17: 0.45370107889175415
# Validation Loss after Epoch 17: 0.45370107889175415, Epochs without improvement: 0
# Epoch 18/250, Batch 1/3, Loss: 0.1592349112033844
# Validation Loss after Epoch 18: 0.3076643645763397
# Validation Loss after Epoch 18: 0.3076643645763397, Epochs without improvement: 0
# Epoch 19/250, Batch 1/3, Loss: 0.15045417845249176
# Validation Loss after Epoch 19: 0.26950135827064514
# Validation Loss after Epoch 19: 0.26950135827064514, Epochs without improvement: 0
# Epoch 20/250, Batch 1/3, Loss: 0.1435089111328125
# Validation Loss after Epoch 20: 0.22959184646606445
# Validation Loss after Epoch 20: 0.22959184646606445, Epochs without improvement: 0
# Epoch 21/250, Batch 1/3, Loss: 0.1317637711763382
# Validation Loss after Epoch 21: 0.20022402703762054
# Validation Loss after Epoch 21: 0.20022402703762054, Epochs without improvement: 0
# Epoch 22/250, Batch 1/3, Loss: 0.12435967475175858
# Validation Loss after Epoch 22: 0.17768608033657074
# Validation Loss after Epoch 22: 0.17768608033657074, Epochs without improvement: 0
# Epoch 23/250, Batch 1/3, Loss: 0.114527128636837
# Validation Loss after Epoch 23: 0.1668895035982132
# Validation Loss after Epoch 23: 0.1668895035982132, Epochs without improvement: 0
# Epoch 24/250, Batch 1/3, Loss: 0.1139783188700676
# Validation Loss after Epoch 24: 0.16027872264385223
# Validation Loss after Epoch 24: 0.16027872264385223, Epochs without improvement: 0
# Epoch 25/250, Batch 1/3, Loss: 0.107590451836586
# Validation Loss after Epoch 25: 0.15789340436458588
# Validation Loss after Epoch 25: 0.15789340436458588, Epochs without improvement: 0
# Epoch 26/250, Batch 1/3, Loss: 0.1044151708483696
# Validation Loss after Epoch 26: 0.1565505713224411
# Validation Loss after Epoch 26: 0.1565505713224411, Epochs without improvement: 0
# Epoch 27/250, Batch 1/3, Loss: 0.10024792701005936
# Validation Loss after Epoch 27: 0.15623928606510162
# Validation Loss after Epoch 27: 0.15623928606510162, Epochs without improvement: 0
# Epoch 28/250, Batch 1/3, Loss: 0.09537234157323837
# Validation Loss after Epoch 28: 0.15718583762645721
# Validation Loss after Epoch 28: 0.15718583762645721, Epochs without improvement: 1
# Epoch 29/250, Batch 1/3, Loss: 0.08994661271572113
# Validation Loss after Epoch 29: 0.16118983924388885
# Validation Loss after Epoch 29: 0.16118983924388885, Epochs without improvement: 2
# Epoch 30/250, Batch 1/3, Loss: 0.08561474829912186
# Validation Loss after Epoch 30: 0.15747018158435822
# Validation Loss after Epoch 30: 0.15747018158435822, Epochs without improvement: 3
# Epoch 31/250, Batch 1/3, Loss: 0.0842810645699501
# Validation Loss after Epoch 31: 0.15371540188789368
# Validation Loss after Epoch 31: 0.15371540188789368, Epochs without improvement: 0
# Epoch 32/250, Batch 1/3, Loss: 0.07822581380605698
# Validation Loss after Epoch 32: 0.15119723975658417
# Validation Loss after Epoch 32: 0.15119723975658417, Epochs without improvement: 0
# Epoch 33/250, Batch 1/3, Loss: 0.07388811558485031
# Validation Loss after Epoch 33: 0.15616486966609955
# Validation Loss after Epoch 33: 0.15616486966609955, Epochs without improvement: 1
# Epoch 34/250, Batch 1/3, Loss: 0.07436749339103699
# Validation Loss after Epoch 34: 0.1518380045890808
# Validation Loss after Epoch 34: 0.1518380045890808, Epochs without improvement: 2
# Epoch 35/250, Batch 1/3, Loss: 0.07135047018527985
# Validation Loss after Epoch 35: 0.14797884225845337
# Validation Loss after Epoch 35: 0.14797884225845337, Epochs without improvement: 0
# Epoch 36/250, Batch 1/3, Loss: 0.06960722804069519
# Validation Loss after Epoch 36: 0.14671604335308075
# Validation Loss after Epoch 36: 0.14671604335308075, Epochs without improvement: 0
# Epoch 37/250, Batch 1/3, Loss: 0.06723760068416595
# Validation Loss after Epoch 37: 0.14169859886169434
# Validation Loss after Epoch 37: 0.14169859886169434, Epochs without improvement: 0
# Epoch 38/250, Batch 1/3, Loss: 0.06527160108089447
# Validation Loss after Epoch 38: 0.1453123837709427
# Validation Loss after Epoch 38: 0.1453123837709427, Epochs without improvement: 1
# Epoch 39/250, Batch 1/3, Loss: 0.06349174678325653
# Validation Loss after Epoch 39: 0.15138979256153107
# Validation Loss after Epoch 39: 0.15138979256153107, Epochs without improvement: 2
# Epoch 40/250, Batch 1/3, Loss: 0.061021409928798676
# Validation Loss after Epoch 40: 0.15375956892967224
# Validation Loss after Epoch 40: 0.15375956892967224, Epochs without improvement: 3
# Epoch 41/250, Batch 1/3, Loss: 0.05967595800757408
# Validation Loss after Epoch 41: 0.15484555065631866
# Validation Loss after Epoch 41: 0.15484555065631866, Epochs without improvement: 4
# Epoch 42/250, Batch 1/3, Loss: 0.056430090218782425
# Validation Loss after Epoch 42: 0.15220236778259277
# Validation Loss after Epoch 42: 0.15220236778259277, Epochs without improvement: 5
# Epoch 43/250, Batch 1/3, Loss: 0.057437606155872345
# Validation Loss after Epoch 43: 0.14959707856178284
# Validation Loss after Epoch 43: 0.14959707856178284, Epochs without improvement: 6
# Epoch 44/250, Batch 1/3, Loss: 0.05039513111114502
# Validation Loss after Epoch 44: 0.14762187004089355
# Validation Loss after Epoch 44: 0.14762187004089355, Epochs without improvement: 7
# Epoch 45/250, Batch 1/3, Loss: 0.05058981105685234
# Validation Loss after Epoch 45: 0.1461499035358429
# Validation Loss after Epoch 45: 0.1461499035358429, Epochs without improvement: 8
# Epoch 46/250, Batch 1/3, Loss: 0.052370280027389526
# Validation Loss after Epoch 46: 0.14753136038780212
# Validation Loss after Epoch 46: 0.14753136038780212, Epochs without improvement: 9
# Epoch 47/250, Batch 1/3, Loss: 0.04992349073290825
# Validation Loss after Epoch 47: 0.1449270248413086
# Validation Loss after Epoch 47: 0.1449270248413086, Epochs without improvement: 10
# Early stopping triggered
# Subset size 100 - Test Loss: 0.1353, Test Accuracy: 95.43%, Average Dice Score: 0.9542
# Training on subset size: 250
# Epoch 1/250, Batch 1/6, Loss: 1.161895990371704
# Validation Loss after Epoch 1: 1.075466811656952
# Validation Loss after Epoch 1: 1.075466811656952, Epochs without improvement: 0
# Epoch 2/250, Batch 1/6, Loss: 0.5651174783706665
# Validation Loss after Epoch 2: 1.0994728207588196
# Validation Loss after Epoch 2: 1.0994728207588196, Epochs without improvement: 1
# Epoch 3/250, Batch 1/6, Loss: 0.4406079947948456
# Validation Loss after Epoch 3: 1.297816812992096
# Validation Loss after Epoch 3: 1.297816812992096, Epochs without improvement: 2
# Epoch 4/250, Batch 1/6, Loss: 0.36624908447265625
# Validation Loss after Epoch 4: 1.3492467403411865
# Validation Loss after Epoch 4: 1.3492467403411865, Epochs without improvement: 3
# Epoch 5/250, Batch 1/6, Loss: 0.30619966983795166
# Validation Loss after Epoch 5: 1.2008515000343323
# Validation Loss after Epoch 5: 1.2008515000343323, Epochs without improvement: 4
# Epoch 6/250, Batch 1/6, Loss: 0.2652398347854614
# Validation Loss after Epoch 6: 1.117283046245575
# Validation Loss after Epoch 6: 1.117283046245575, Epochs without improvement: 5
# Epoch 7/250, Batch 1/6, Loss: 0.2338613122701645
# Validation Loss after Epoch 7: 0.9656404554843903
# Validation Loss after Epoch 7: 0.9656404554843903, Epochs without improvement: 0
# Epoch 8/250, Batch 1/6, Loss: 0.2067926675081253
# Validation Loss after Epoch 8: 0.8397048115730286
# Validation Loss after Epoch 8: 0.8397048115730286, Epochs without improvement: 0
# Epoch 9/250, Batch 1/6, Loss: 0.1842491626739502
# Validation Loss after Epoch 9: 0.6053356528282166
# Validation Loss after Epoch 9: 0.6053356528282166, Epochs without improvement: 0
# Epoch 10/250, Batch 1/6, Loss: 0.16444630920886993
# Validation Loss after Epoch 10: 0.37593694031238556
# Validation Loss after Epoch 10: 0.37593694031238556, Epochs without improvement: 0
# Epoch 11/250, Batch 1/6, Loss: 0.1473253220319748
# Validation Loss after Epoch 11: 0.21858078241348267
# Validation Loss after Epoch 11: 0.21858078241348267, Epochs without improvement: 0
# Epoch 12/250, Batch 1/6, Loss: 0.13705970346927643
# Validation Loss after Epoch 12: 0.16507134586572647
# Validation Loss after Epoch 12: 0.16507134586572647, Epochs without improvement: 0
# Epoch 13/250, Batch 1/6, Loss: 0.11973120272159576
# Validation Loss after Epoch 13: 0.1447720006108284
# Validation Loss after Epoch 13: 0.1447720006108284, Epochs without improvement: 0
# Epoch 14/250, Batch 1/6, Loss: 0.11090646684169769
# Validation Loss after Epoch 14: 0.12893111258745193
# Validation Loss after Epoch 14: 0.12893111258745193, Epochs without improvement: 0
# Epoch 15/250, Batch 1/6, Loss: 0.10409660637378693
# Validation Loss after Epoch 15: 0.1193704716861248
# Validation Loss after Epoch 15: 0.1193704716861248, Epochs without improvement: 0
# Epoch 16/250, Batch 1/6, Loss: 0.095952108502388
# Validation Loss after Epoch 16: 0.11165966093540192
# Validation Loss after Epoch 16: 0.11165966093540192, Epochs without improvement: 0
# Epoch 17/250, Batch 1/6, Loss: 0.094535693526268
# Validation Loss after Epoch 17: 0.10991646721959114
# Validation Loss after Epoch 17: 0.10991646721959114, Epochs without improvement: 0
# Epoch 18/250, Batch 1/6, Loss: 0.08503163605928421
# Validation Loss after Epoch 18: 0.10016553103923798
# Validation Loss after Epoch 18: 0.10016553103923798, Epochs without improvement: 0
# Epoch 19/250, Batch 1/6, Loss: 0.07910466194152832
# Validation Loss after Epoch 19: 0.10005868226289749
# Validation Loss after Epoch 19: 0.10005868226289749, Epochs without improvement: 0
# Epoch 20/250, Batch 1/6, Loss: 0.07747077941894531
# Validation Loss after Epoch 20: 0.09820877760648727
# Validation Loss after Epoch 20: 0.09820877760648727, Epochs without improvement: 0
# Epoch 21/250, Batch 1/6, Loss: 0.07365470379590988
# Validation Loss after Epoch 21: 0.0912136659026146
# Validation Loss after Epoch 21: 0.0912136659026146, Epochs without improvement: 0
# Epoch 22/250, Batch 1/6, Loss: 0.06990563869476318
# Validation Loss after Epoch 22: 0.09174535050988197
# Validation Loss after Epoch 22: 0.09174535050988197, Epochs without improvement: 1
# Epoch 23/250, Batch 1/6, Loss: 0.06669548898935318
# Validation Loss after Epoch 23: 0.09158478304743767
# Validation Loss after Epoch 23: 0.09158478304743767, Epochs without improvement: 2
# Epoch 24/250, Batch 1/6, Loss: 0.06704208999872208
# Validation Loss after Epoch 24: 0.0919898971915245
# Validation Loss after Epoch 24: 0.0919898971915245, Epochs without improvement: 3
# Epoch 25/250, Batch 1/6, Loss: 0.06490319222211838
# Validation Loss after Epoch 25: 0.08713093400001526
# Validation Loss after Epoch 25: 0.08713093400001526, Epochs without improvement: 0
# Epoch 26/250, Batch 1/6, Loss: 0.06418796628713608
# Validation Loss after Epoch 26: 0.0890963152050972
# Validation Loss after Epoch 26: 0.0890963152050972, Epochs without improvement: 1
# Epoch 27/250, Batch 1/6, Loss: 0.061587586998939514
# Validation Loss after Epoch 27: 0.08597283810377121
# Validation Loss after Epoch 27: 0.08597283810377121, Epochs without improvement: 0
# Epoch 28/250, Batch 1/6, Loss: 0.0561453178524971
# Validation Loss after Epoch 28: 0.08579528704285622
# Validation Loss after Epoch 28: 0.08579528704285622, Epochs without improvement: 0
# Epoch 29/250, Batch 1/6, Loss: 0.05433232709765434
# Validation Loss after Epoch 29: 0.08444912359118462
# Validation Loss after Epoch 29: 0.08444912359118462, Epochs without improvement: 0
# Epoch 30/250, Batch 1/6, Loss: 0.052745383232831955
# Validation Loss after Epoch 30: 0.08458564057946205
# Validation Loss after Epoch 30: 0.08458564057946205, Epochs without improvement: 1
# Epoch 31/250, Batch 1/6, Loss: 0.05558164417743683
# Validation Loss after Epoch 31: 0.09025593847036362
# Validation Loss after Epoch 31: 0.09025593847036362, Epochs without improvement: 2
# Epoch 32/250, Batch 1/6, Loss: 0.05039846897125244
# Validation Loss after Epoch 32: 0.08693468570709229
# Validation Loss after Epoch 32: 0.08693468570709229, Epochs without improvement: 3
# Epoch 33/250, Batch 1/6, Loss: 0.04949600622057915
# Validation Loss after Epoch 33: 0.09058133512735367
# Validation Loss after Epoch 33: 0.09058133512735367, Epochs without improvement: 4
# Epoch 34/250, Batch 1/6, Loss: 0.048116911202669144
# Validation Loss after Epoch 34: 0.0959615632891655
# Validation Loss after Epoch 34: 0.0959615632891655, Epochs without improvement: 5
# Epoch 35/250, Batch 1/6, Loss: 0.049846433103084564
# Validation Loss after Epoch 35: 0.08940891921520233
# Validation Loss after Epoch 35: 0.08940891921520233, Epochs without improvement: 6
# Epoch 36/250, Batch 1/6, Loss: 0.04761805012822151
# Validation Loss after Epoch 36: 0.08570549637079239
# Validation Loss after Epoch 36: 0.08570549637079239, Epochs without improvement: 7
# Epoch 37/250, Batch 1/6, Loss: 0.0451638400554657
# Validation Loss after Epoch 37: 0.08578601479530334
# Validation Loss after Epoch 37: 0.08578601479530334, Epochs without improvement: 8
# Epoch 38/250, Batch 1/6, Loss: 0.04500985145568848
# Validation Loss after Epoch 38: 0.08693122491240501
# Validation Loss after Epoch 38: 0.08693122491240501, Epochs without improvement: 9
# Epoch 39/250, Batch 1/6, Loss: 0.04267864674329758
# Validation Loss after Epoch 39: 0.0876317210495472
# Validation Loss after Epoch 39: 0.0876317210495472, Epochs without improvement: 10
# Early stopping triggered
# Subset size 250 - Test Loss: 0.0901, Test Accuracy: 96.68%, Average Dice Score: 0.9658
# Training on subset size: 500
# Epoch 1/250, Batch 1/11, Loss: 1.1425892114639282
# Epoch 1/250, Batch 11/11, Loss: 0.4505728483200073
# Validation Loss after Epoch 1: 1.138659119606018
# Validation Loss after Epoch 1: 1.138659119606018, Epochs without improvement: 0
# Epoch 2/250, Batch 1/11, Loss: 0.43593525886535645
# Epoch 2/250, Batch 11/11, Loss: 0.33116599917411804
# Validation Loss after Epoch 2: 1.5766490300496419
# Validation Loss after Epoch 2: 1.5766490300496419, Epochs without improvement: 1
# Epoch 3/250, Batch 1/11, Loss: 0.31915080547332764
# Epoch 3/250, Batch 11/11, Loss: 0.25611254572868347
# Validation Loss after Epoch 3: 1.3595903714497883
# Validation Loss after Epoch 3: 1.3595903714497883, Epochs without improvement: 2
# Epoch 4/250, Batch 1/11, Loss: 0.2473555952310562
# Epoch 4/250, Batch 11/11, Loss: 0.20267027616500854
# Validation Loss after Epoch 4: 1.114893118540446
# Validation Loss after Epoch 4: 1.114893118540446, Epochs without improvement: 0
# Epoch 5/250, Batch 1/11, Loss: 0.2023666650056839
# Epoch 5/250, Batch 11/11, Loss: 0.1666295826435089
# Validation Loss after Epoch 5: 0.6477958758672079
# Validation Loss after Epoch 5: 0.6477958758672079, Epochs without improvement: 0
# Epoch 6/250, Batch 1/11, Loss: 0.16446508467197418
# Epoch 6/250, Batch 11/11, Loss: 0.14411768317222595
# Validation Loss after Epoch 6: 0.2889702022075653
# Validation Loss after Epoch 6: 0.2889702022075653, Epochs without improvement: 0
# Epoch 7/250, Batch 1/11, Loss: 0.13799984753131866
# Epoch 7/250, Batch 11/11, Loss: 0.12370464950799942
# Validation Loss after Epoch 7: 0.17266057431697845
# Validation Loss after Epoch 7: 0.17266057431697845, Epochs without improvement: 0
# Epoch 8/250, Batch 1/11, Loss: 0.12124413251876831
# Epoch 8/250, Batch 11/11, Loss: 0.11394445598125458
# Validation Loss after Epoch 8: 0.13295280188322067
# Validation Loss after Epoch 8: 0.13295280188322067, Epochs without improvement: 0
# Epoch 9/250, Batch 1/11, Loss: 0.10870333760976791
# Epoch 9/250, Batch 11/11, Loss: 0.10347405821084976
# Validation Loss after Epoch 9: 0.11409284919500351
# Validation Loss after Epoch 9: 0.11409284919500351, Epochs without improvement: 0
# Epoch 10/250, Batch 1/11, Loss: 0.09768177568912506
# Epoch 10/250, Batch 11/11, Loss: 0.10102902352809906
# Validation Loss after Epoch 10: 0.09381564209858577
# Validation Loss after Epoch 10: 0.09381564209858577, Epochs without improvement: 0
# Epoch 11/250, Batch 1/11, Loss: 0.08939618617296219
# Epoch 11/250, Batch 11/11, Loss: 0.09358585625886917
# Validation Loss after Epoch 11: 0.08169593413670857
# Validation Loss after Epoch 11: 0.08169593413670857, Epochs without improvement: 0
# Epoch 12/250, Batch 1/11, Loss: 0.08403322845697403
# Epoch 12/250, Batch 11/11, Loss: 0.08627701550722122
# Validation Loss after Epoch 12: 0.08139408628145854
# Validation Loss after Epoch 12: 0.08139408628145854, Epochs without improvement: 0
# Epoch 13/250, Batch 1/11, Loss: 0.07856038957834244
# Epoch 13/250, Batch 11/11, Loss: 0.0828440934419632
# Validation Loss after Epoch 13: 0.08124062915643056
# Validation Loss after Epoch 13: 0.08124062915643056, Epochs without improvement: 0
# Epoch 14/250, Batch 1/11, Loss: 0.071468785405159
# Epoch 14/250, Batch 11/11, Loss: 0.07775910943746567
# Validation Loss after Epoch 14: 0.07760961353778839
# Validation Loss after Epoch 14: 0.07760961353778839, Epochs without improvement: 0
# Epoch 15/250, Batch 1/11, Loss: 0.07059986889362335
# Epoch 15/250, Batch 11/11, Loss: 0.0751001313328743
# Validation Loss after Epoch 15: 0.0693319799999396
# Validation Loss after Epoch 15: 0.0693319799999396, Epochs without improvement: 0
# Epoch 16/250, Batch 1/11, Loss: 0.06331146508455276
# Epoch 16/250, Batch 11/11, Loss: 0.07288353890180588
# Validation Loss after Epoch 16: 0.06777403876185417
# Validation Loss after Epoch 16: 0.06777403876185417, Epochs without improvement: 0
# Epoch 17/250, Batch 1/11, Loss: 0.06397461146116257
# Epoch 17/250, Batch 11/11, Loss: 0.0679694339632988
# Validation Loss after Epoch 17: 0.06695518021782239
# Validation Loss after Epoch 17: 0.06695518021782239, Epochs without improvement: 0
# Epoch 18/250, Batch 1/11, Loss: 0.06040676310658455
# Epoch 18/250, Batch 11/11, Loss: 0.0634051188826561
# Validation Loss after Epoch 18: 0.06201018517216047
# Validation Loss after Epoch 18: 0.06201018517216047, Epochs without improvement: 0
# Epoch 19/250, Batch 1/11, Loss: 0.055037856101989746
# Epoch 19/250, Batch 11/11, Loss: 0.05986519902944565
# Validation Loss after Epoch 19: 0.06584799910585086
# Validation Loss after Epoch 19: 0.06584799910585086, Epochs without improvement: 1
# Epoch 20/250, Batch 1/11, Loss: 0.053461190313100815
# Epoch 20/250, Batch 11/11, Loss: 0.06307283043861389
# Validation Loss after Epoch 20: 0.06245944897333781
# Validation Loss after Epoch 20: 0.06245944897333781, Epochs without improvement: 2
# Epoch 21/250, Batch 1/11, Loss: 0.053635191172361374
# Epoch 21/250, Batch 11/11, Loss: 0.06047452613711357
# Validation Loss after Epoch 21: 0.06701678782701492
# Validation Loss after Epoch 21: 0.06701678782701492, Epochs without improvement: 3
# Epoch 22/250, Batch 1/11, Loss: 0.05393310636281967
# Epoch 22/250, Batch 11/11, Loss: 0.05915512517094612
# Validation Loss after Epoch 22: 0.061461254954338074
# Validation Loss after Epoch 22: 0.061461254954338074, Epochs without improvement: 0
# Epoch 23/250, Batch 1/11, Loss: 0.050498589873313904
# Epoch 23/250, Batch 11/11, Loss: 0.05691034719347954
# Validation Loss after Epoch 23: 0.057443720599015556
# Validation Loss after Epoch 23: 0.057443720599015556, Epochs without improvement: 0
# Epoch 24/250, Batch 1/11, Loss: 0.04890976846218109
# Epoch 24/250, Batch 11/11, Loss: 0.05548161268234253
# Validation Loss after Epoch 24: 0.059856915225585304
# Validation Loss after Epoch 24: 0.059856915225585304, Epochs without improvement: 1
# Epoch 25/250, Batch 1/11, Loss: 0.04560201242566109
# Epoch 25/250, Batch 11/11, Loss: 0.05710720270872116
# Validation Loss after Epoch 25: 0.06010869269569715
# Validation Loss after Epoch 25: 0.06010869269569715, Epochs without improvement: 2
# Epoch 26/250, Batch 1/11, Loss: 0.045779939740896225
# Epoch 26/250, Batch 11/11, Loss: 0.0520225390791893
# Validation Loss after Epoch 26: 0.06009539092580477
# Validation Loss after Epoch 26: 0.06009539092580477, Epochs without improvement: 3
# Epoch 27/250, Batch 1/11, Loss: 0.045611295849084854
# Epoch 27/250, Batch 11/11, Loss: 0.050273068249225616
# Validation Loss after Epoch 27: 0.057161288956801094
# Validation Loss after Epoch 27: 0.057161288956801094, Epochs without improvement: 0
# Epoch 28/250, Batch 1/11, Loss: 0.04401771351695061
# Epoch 28/250, Batch 11/11, Loss: 0.05085257813334465
# Validation Loss after Epoch 28: 0.05505188306172689
# Validation Loss after Epoch 28: 0.05505188306172689, Epochs without improvement: 0
# Epoch 29/250, Batch 1/11, Loss: 0.044894929975271225
# Epoch 29/250, Batch 11/11, Loss: 0.050349585711956024
# Validation Loss after Epoch 29: 0.05861299609144529
# Validation Loss after Epoch 29: 0.05861299609144529, Epochs without improvement: 1
# Epoch 30/250, Batch 1/11, Loss: 0.042689934372901917
# Epoch 30/250, Batch 11/11, Loss: 0.05140826478600502
# Validation Loss after Epoch 30: 0.056580718606710434
# Validation Loss after Epoch 30: 0.056580718606710434, Epochs without improvement: 2
# Epoch 31/250, Batch 1/11, Loss: 0.043106816709041595
# Epoch 31/250, Batch 11/11, Loss: 0.04916515573859215
# Validation Loss after Epoch 31: 0.055270757526159286
# Validation Loss after Epoch 31: 0.055270757526159286, Epochs without improvement: 3
# Epoch 32/250, Batch 1/11, Loss: 0.042898040264844894
# Epoch 32/250, Batch 11/11, Loss: 0.04502944275736809
# Validation Loss after Epoch 32: 0.05721878012021383
# Validation Loss after Epoch 32: 0.05721878012021383, Epochs without improvement: 4
# Epoch 33/250, Batch 1/11, Loss: 0.04024588689208031
# Epoch 33/250, Batch 11/11, Loss: 0.046832695603370667
# Validation Loss after Epoch 33: 0.054969956477483116
# Validation Loss after Epoch 33: 0.054969956477483116, Epochs without improvement: 0
# Epoch 34/250, Batch 1/11, Loss: 0.039412859827280045
# Epoch 34/250, Batch 11/11, Loss: 0.048271339386701584
# Validation Loss after Epoch 34: 0.0589080403248469
# Validation Loss after Epoch 34: 0.0589080403248469, Epochs without improvement: 1
# Epoch 35/250, Batch 1/11, Loss: 0.03890170156955719
# Epoch 35/250, Batch 11/11, Loss: 0.04497445747256279
# Validation Loss after Epoch 35: 0.058609245965878166
# Validation Loss after Epoch 35: 0.058609245965878166, Epochs without improvement: 2
# Epoch 36/250, Batch 1/11, Loss: 0.04027537256479263
# Epoch 36/250, Batch 11/11, Loss: 0.04293098300695419
# Validation Loss after Epoch 36: 0.05636974051594734
# Validation Loss after Epoch 36: 0.05636974051594734, Epochs without improvement: 3
# Epoch 37/250, Batch 1/11, Loss: 0.04023638740181923
# Epoch 37/250, Batch 11/11, Loss: 0.04497438669204712
# Validation Loss after Epoch 37: 0.057666923850774765
# Validation Loss after Epoch 37: 0.057666923850774765, Epochs without improvement: 4
# Epoch 38/250, Batch 1/11, Loss: 0.03846034035086632
# Epoch 38/250, Batch 11/11, Loss: 0.04293467476963997
# Validation Loss after Epoch 38: 0.05795693894227346
# Validation Loss after Epoch 38: 0.05795693894227346, Epochs without improvement: 5
# Epoch 39/250, Batch 1/11, Loss: 0.038433801382780075
# Epoch 39/250, Batch 11/11, Loss: 0.03933719918131828
# Validation Loss after Epoch 39: 0.05515342826644579
# Validation Loss after Epoch 39: 0.05515342826644579, Epochs without improvement: 6
# Epoch 40/250, Batch 1/11, Loss: 0.03935446962714195
# Epoch 40/250, Batch 11/11, Loss: 0.0408148318529129
# Validation Loss after Epoch 40: 0.053654598693052925
# Validation Loss after Epoch 40: 0.053654598693052925, Epochs without improvement: 0
# Epoch 41/250, Batch 1/11, Loss: 0.036887697875499725
# Epoch 41/250, Batch 11/11, Loss: 0.03979095071554184
# Validation Loss after Epoch 41: 0.05637463554739952
# Validation Loss after Epoch 41: 0.05637463554739952, Epochs without improvement: 1
# Epoch 42/250, Batch 1/11, Loss: 0.033703915774822235
# Epoch 42/250, Batch 11/11, Loss: 0.040687818080186844
# Validation Loss after Epoch 42: 0.05889403074979782
# Validation Loss after Epoch 42: 0.05889403074979782, Epochs without improvement: 2
# Epoch 43/250, Batch 1/11, Loss: 0.0355897881090641
# Epoch 43/250, Batch 11/11, Loss: 0.04100007936358452
# Validation Loss after Epoch 43: 0.05579474816719691
# Validation Loss after Epoch 43: 0.05579474816719691, Epochs without improvement: 3
# Epoch 44/250, Batch 1/11, Loss: 0.03506800904870033
# Epoch 44/250, Batch 11/11, Loss: 0.03855292126536369
# Validation Loss after Epoch 44: 0.05578424781560898
# Validation Loss after Epoch 44: 0.05578424781560898, Epochs without improvement: 4
# Epoch 45/250, Batch 1/11, Loss: 0.03416616469621658
# Epoch 45/250, Batch 11/11, Loss: 0.03808820620179176
# Validation Loss after Epoch 45: 0.05522563184301058
# Validation Loss after Epoch 45: 0.05522563184301058, Epochs without improvement: 5
# Epoch 46/250, Batch 1/11, Loss: 0.0332314632833004
# Epoch 46/250, Batch 11/11, Loss: 0.03933702036738396
# Validation Loss after Epoch 46: 0.053506853679815926
# Validation Loss after Epoch 46: 0.053506853679815926, Epochs without improvement: 0
# Epoch 47/250, Batch 1/11, Loss: 0.033227235078811646
# Epoch 47/250, Batch 11/11, Loss: 0.03855244815349579
# Validation Loss after Epoch 47: 0.05696967119971911
# Validation Loss after Epoch 47: 0.05696967119971911, Epochs without improvement: 1
# Epoch 48/250, Batch 1/11, Loss: 0.030709158629179
# Epoch 48/250, Batch 11/11, Loss: 0.03719155490398407
# Validation Loss after Epoch 48: 0.05624165137608846
# Validation Loss after Epoch 48: 0.05624165137608846, Epochs without improvement: 2
# Epoch 49/250, Batch 1/11, Loss: 0.03307395055890083
# Epoch 49/250, Batch 11/11, Loss: 0.035243626683950424
# Validation Loss after Epoch 49: 0.05617751181125641
# Validation Loss after Epoch 49: 0.05617751181125641, Epochs without improvement: 3
# Epoch 50/250, Batch 1/11, Loss: 0.030939657241106033
# Epoch 50/250, Batch 11/11, Loss: 0.03896993026137352
# Validation Loss after Epoch 50: 0.055739312122265496
# Validation Loss after Epoch 50: 0.055739312122265496, Epochs without improvement: 4
# Epoch 51/250, Batch 1/11, Loss: 0.03135651722550392
# Epoch 51/250, Batch 11/11, Loss: 0.03719324991106987
# Validation Loss after Epoch 51: 0.054853737354278564
# Validation Loss after Epoch 51: 0.054853737354278564, Epochs without improvement: 5
# Epoch 52/250, Batch 1/11, Loss: 0.03108094446361065
# Epoch 52/250, Batch 11/11, Loss: 0.03735266625881195
# Validation Loss after Epoch 52: 0.053502062956492104
# Validation Loss after Epoch 52: 0.053502062956492104, Epochs without improvement: 0
# Epoch 53/250, Batch 1/11, Loss: 0.02870519831776619
# Epoch 53/250, Batch 11/11, Loss: 0.03650486469268799
# Validation Loss after Epoch 53: 0.0550012451906999
# Validation Loss after Epoch 53: 0.0550012451906999, Epochs without improvement: 1
# Epoch 54/250, Batch 1/11, Loss: 0.031231962144374847
# Epoch 54/250, Batch 11/11, Loss: 0.0384199395775795
# Validation Loss after Epoch 54: 0.05637591332197189
# Validation Loss after Epoch 54: 0.05637591332197189, Epochs without improvement: 2
# Epoch 55/250, Batch 1/11, Loss: 0.03244360163807869
# Epoch 55/250, Batch 11/11, Loss: 0.03631850332021713
# Validation Loss after Epoch 55: 0.05961724122365316
# Validation Loss after Epoch 55: 0.05961724122365316, Epochs without improvement: 3
# Epoch 56/250, Batch 1/11, Loss: 0.029222482815384865
# Epoch 56/250, Batch 11/11, Loss: 0.03754989430308342
# Validation Loss after Epoch 56: 0.05934740975499153
# Validation Loss after Epoch 56: 0.05934740975499153, Epochs without improvement: 4
# Epoch 57/250, Batch 1/11, Loss: 0.028087221086025238
# Epoch 57/250, Batch 11/11, Loss: 0.03609973192214966
# Validation Loss after Epoch 57: 0.05825734635194143
# Validation Loss after Epoch 57: 0.05825734635194143, Epochs without improvement: 5
# Epoch 58/250, Batch 1/11, Loss: 0.02920634113252163
# Epoch 58/250, Batch 11/11, Loss: 0.03543609008193016
# Validation Loss after Epoch 58: 0.057223898669083915
# Validation Loss after Epoch 58: 0.057223898669083915, Epochs without improvement: 6
# Epoch 59/250, Batch 1/11, Loss: 0.02808326482772827
# Epoch 59/250, Batch 11/11, Loss: 0.03441322222352028
# Validation Loss after Epoch 59: 0.05413181583086649
# Validation Loss after Epoch 59: 0.05413181583086649, Epochs without improvement: 7
# Epoch 60/250, Batch 1/11, Loss: 0.027192870154976845
# Epoch 60/250, Batch 11/11, Loss: 0.032799527049064636
# Validation Loss after Epoch 60: 0.05590531726678213
# Validation Loss after Epoch 60: 0.05590531726678213, Epochs without improvement: 8
# Epoch 61/250, Batch 1/11, Loss: 0.02813531830906868
# Epoch 61/250, Batch 11/11, Loss: 0.031849443912506104
# Validation Loss after Epoch 61: 0.058435986439387
# Validation Loss after Epoch 61: 0.058435986439387, Epochs without improvement: 9
# Epoch 62/250, Batch 1/11, Loss: 0.028459874913096428
# Epoch 62/250, Batch 11/11, Loss: 0.03182468190789223
# Validation Loss after Epoch 62: 0.05747945482532183
# Validation Loss after Epoch 62: 0.05747945482532183, Epochs without improvement: 10
# Early stopping triggered
# Subset size 500 - Test Loss: 0.0617, Test Accuracy: 97.46%, Average Dice Score: 0.9747

# %%
torch.save(model.state_dict(), '128x128smaller_subsets_with_Early_Stoppage.pth')

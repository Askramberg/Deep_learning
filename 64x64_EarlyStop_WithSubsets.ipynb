# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
import torch.nn.functional as F


from torch.utils.data import Dataset
from PIL import Image
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, image_paths, label_paths):
        self.image_paths = image_paths
        self.label_paths = label_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load the image using PIL
        with Image.open(self.image_paths[idx]) as img:
            np_image = np.array(img, dtype=np.float32)

        # Normalize the image
        normalized_image = np_image / 65535.0  # Assuming 16-bit images

        # Load and process the label data using PIL
        with Image.open(self.label_paths[idx]) as label_img:
            label_array = np.array(label_img, dtype=np.float32)

        grayscale_to_class_mapping = {0: 0, 128: 1, 255: 2} # Maps gray-levels to class

        # Map grayscale values to class labels
        mapped_labels = np.copy(label_array)
        for grayscale_value, class_id in grayscale_to_class_mapping.items():
            mapped_labels[label_array == grayscale_value] = class_id

        # Convert to PyTorch tensors
        image_tensor = torch.from_numpy(normalized_image).unsqueeze(0) # Add channel dimension
        label_tensor = torch.from_numpy(mapped_labels).long() # Ensure label tensor is long type

        return image_tensor, label_tensor

# %%
### Label images ###
# white class - 255 nickel
# gray class - 128 ysz
# black class - 0 pores

class UNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()

        # Define a helper function for creating a block
        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
                nn.Dropout(p=0.1)
            )

        # Encoder
        self.e11 = conv_block(1, 64)
        self.e12 = conv_block(64, 64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e21 = conv_block(64, 128)
        self.e22 = conv_block(128, 128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e31 = conv_block(128, 256)
        self.e32 = conv_block(256, 256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e41 = conv_block(256, 512)
        self.e42 = conv_block(512, 512)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e51 = conv_block(512, 1024)
        self.e52 = conv_block(1024, 1024)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.d11 = conv_block(1024, 512)
        self.d12 = conv_block(512, 512)

        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.d21 = conv_block(512, 256)
        self.d22 = conv_block(256, 256)

        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.d31 = conv_block(256, 128)
        self.d32 = conv_block(128, 128)

        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.d41 = conv_block(128, 64)
        self.d42 = conv_block(64, 64)

        # Output layer
        self.outconv = nn.Conv2d(64, n_class, kernel_size=1)

    def forward(self, x):
        # Encoder
        xe11 = self.e11(x)
        xe12 = self.e12(xe11)
        xp1 = self.pool1(xe12)

        xe21 = self.e21(xp1)
        xe22 = self.e22(xe21)
        xp2 = self.pool2(xe22)

        xe31 = self.e31(xp2)
        xe32 = self.e32(xe31)
        xp3 = self.pool3(xe32)

        xe41 = self.e41(xp3)
        xe42 = self.e42(xe41)
        xp4 = self.pool4(xe42)

        xe51 = self.e51(xp4)
        xe52 = self.e52(xe51)

        # Decoder
        xu1 = self.upconv1(xe52)
        xu11 = torch.cat([xu1, xe42], dim=1)
        xd11 = self.d11(xu11)
        xd12 = self.d12(xd11)

        xu2 = self.upconv2(xd12)
        xu22 = torch.cat([xu2, xe32], dim=1)
        xd21 = self.d21(xu22)
        xd22 = self.d22(xd21)

        xu3 = self.upconv3(xd22)
        xu33 = torch.cat([xu3, xe22], dim=1)
        xd31 = self.d31(xu33)
        xd32 = self.d32(xd31)

        xu4 = self.upconv4(xd32)
        xu44 = torch.cat([xu4, xe12], dim=1)
        xd41 = self.d41(xu44)
        xd42 = self.d42(xd41)

        # Output layer
        out = self.outconv(xd42)

        return out

# %%
from torch.utils.data import DataLoader, random_split
from torch import optim
import torch
import os
import matplotlib.pyplot as plt

def dice_coefficient(predicted, target, num_classes):
    dice_scores = []  # To store dice coefficient for each class

    # Convert predictions and targets to one-hot encoded form
    predicted_one_hot = F.one_hot(predicted, num_classes).permute(0, 3, 1, 2).float()
    target_one_hot = F.one_hot(target, num_classes).permute(0, 3, 1, 2).float()

    # Calculate Dice coefficient for each class
    for class_index in range(num_classes):
        intersection = (predicted_one_hot[:, class_index, :, :] * target_one_hot[:, class_index, :, :]).sum()
        union = predicted_one_hot[:, class_index, :, :].sum() + target_one_hot[:, class_index, :, :].sum()
        dice_score = (2 * intersection + 1e-6) / (union + 1e-6)  # Adding a small epsilon to avoid division by zero
        dice_scores.append(dice_score)

    # Average Dice score across all classes
    avg_dice_score = sum(dice_scores) / len(dice_scores)
    return avg_dice_score.item()  # Return the value as a Python scalar

def get_image_paths(data_dir, label_dir):
    data_paths = [os.path.join(data_dir, img) for img in sorted(os.listdir(data_dir))]
    label_paths = [os.path.join(label_dir, lbl) for lbl in sorted(os.listdir(label_dir))]
    return data_paths, label_paths

def create_subsets(dataset, subset_sizes):
    subsets = {}
    for size in subset_sizes:
        if size == len(dataset):
            subsets[size] = dataset  # Use the full dataset
        else:
            subset, _ = random_split(dataset, [size, len(dataset) - size])
            subsets[size] = subset
    return subsets

def plot_predictions(images, actuals, predicted):
    plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
    for i in range(len(images)):
        # Rescale the images from [0, 1] to [0, 65535]
        image = images[i].squeeze() * 65535

        # Contrast stretching the original image for visualization (directly doing 16bit to 8bit got fucked)
        vmin, vmax = image.min(), image.max()
        image = (image - vmin) / (vmax - vmin)  # Scale pixel values to 0-1 range
        image = (image * 255).to(torch.uint8).cpu().numpy()  # Scale up to 0-255 range and convert to 8-bit

        # Display the original image
        plt.subplot(1, len(images)*3, i*3+1)
        plt.imshow(image, cmap='gray')
        plt.title(f'Original Image')
        plt.axis('off')

        # Display the actual label image
        actual = actuals[i].squeeze()  # Assuming actuals is a batch of label images
        plt.subplot(1, len(images)*3, i*3+2)
        plt.imshow(actual, cmap='gray')
        plt.title(f'Actual Label')
        plt.axis('off')

        # Display the predicted label image
        pred = predicted[i].squeeze()  # Assuming predicted is a batch of label images
        plt.subplot(1, len(images)*3, i*3+3)
        plt.imshow(pred, cmap='gray')
        plt.title(f'Predicted Label')
        plt.axis('off')

    plt.show()

# %%
# Define your dataset paths
data_dir = '/content/gdrive/MyDrive/training_dataset/data_resize64/'
label_dir = '/content/gdrive/MyDrive/training_dataset/label_resize64/'

# Get image paths and create the full dataset
image_paths, label_paths = get_image_paths(data_dir, label_dir)
dataset = CustomDataset(image_paths=image_paths, label_paths=label_paths)

# Define subset sizes including the full dataset size
subset_size = [100, 250, len(dataset)]  # Add the full dataset size

# Create subsets
dataset_subsets = create_subsets(dataset, subset_size)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")

# Training configurations
learning_rate = 0.001
num_epochs = 250  # Adjust as needed

# Early stopping parameters
patience = 10  # Number of epochs to wait after last improvement
best_val_loss = float('inf')  # Initialize best validation loss as infinity
epochs_no_improve = 0  # Counter for epochs without improvement

# Loop over subsets and train the model
for size, subset in dataset_subsets.items():
    print(f"\nTraining on subset size: {size}")

    # Reset early stopping parameters for each subset
    best_val_loss = float('inf')
    epochs_no_improve = 0

    # Split the subset into training, validation, and test datasets
    train_size = int(0.70 * len(subset))
    val_size = int(0.15 * len(subset))
    test_size = len(subset) - train_size - val_size
    train_dataset, val_dataset, test_dataset = random_split(subset, [train_size, val_size, test_size])

    # DataLoader setup
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Model, loss function, and optimizer setup
    model = UNet(n_class=3).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        for batch_idx, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            labels = labels.squeeze(1).long()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item()}")

        # Validation phase
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                labels = labels.squeeze(1).long()
                loss = criterion(outputs, labels)
                val_loss += loss.item()
            val_loss /= len(val_loader)
            print(f"Validation Loss after Epoch {epoch+1}: {val_loss}")

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f"Validation Loss after Epoch {epoch+1}: {val_loss}, Epochs without improvement: {epochs_no_improve}")

        if epochs_no_improve == patience:
            print("Early stopping triggered")
            break


    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        test_loss = 0
        correct = 0
        total = 0
        dice_scores = []

        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probabilities = F.softmax(outputs, dim=1)
            _, predicted = torch.max(probabilities, 1)
            labels = labels.squeeze(1).long()

            loss = criterion(outputs, labels)
            test_loss += loss.item()
            total += labels.numel()
            correct += (predicted == labels).sum().item()

            dice_score = dice_coefficient(predicted, labels, num_classes=3)
            dice_scores.append(dice_score)

        test_loss /= len(test_loader)
        test_accuracy = 100 * correct / total
        average_dice_score = sum(dice_scores) / len(dice_scores)

        print(f"Subset size {size} - Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%, Average Dice Score: {average_dice_score:.4f}")

        # Select a few images (e.g., first 4)
        selected_images = images[:4].cpu()
        actual_labels = labels[:4].cpu()
        predicted_labels = predicted[:4].cpu()

        # Call the function
        plot_predictions(selected_images, actual_labels, predicted_labels)
# Out:
# Using cuda
#
# Training on subset size: 100
# Epoch 1/250, Batch 1/3, Loss: 1.1708166599273682
# Validation Loss after Epoch 1: 1.094045639038086
# Validation Loss after Epoch 1: 1.094045639038086, Epochs without improvement: 0
# Epoch 2/250, Batch 1/3, Loss: 0.47197800874710083
# Validation Loss after Epoch 2: 1.0645278692245483
# Validation Loss after Epoch 2: 1.0645278692245483, Epochs without improvement: 0
# Epoch 3/250, Batch 1/3, Loss: 0.35459500551223755
# Validation Loss after Epoch 3: 1.0842499732971191
# Validation Loss after Epoch 3: 1.0842499732971191, Epochs without improvement: 1
# Epoch 4/250, Batch 1/3, Loss: 0.30194419622421265
# Validation Loss after Epoch 4: 1.2288836240768433
# Validation Loss after Epoch 4: 1.2288836240768433, Epochs without improvement: 2
# Epoch 5/250, Batch 1/3, Loss: 0.26990020275115967
# Validation Loss after Epoch 5: 1.4021888971328735
# Validation Loss after Epoch 5: 1.4021888971328735, Epochs without improvement: 3
# Epoch 6/250, Batch 1/3, Loss: 0.24197442829608917
# Validation Loss after Epoch 6: 1.5849155187606812
# Validation Loss after Epoch 6: 1.5849155187606812, Epochs without improvement: 4
# Epoch 7/250, Batch 1/3, Loss: 0.22109146416187286
# Validation Loss after Epoch 7: 1.7337826490402222
# Validation Loss after Epoch 7: 1.7337826490402222, Epochs without improvement: 5
# Epoch 8/250, Batch 1/3, Loss: 0.2050105631351471
# Validation Loss after Epoch 8: 1.9012748003005981
# Validation Loss after Epoch 8: 1.9012748003005981, Epochs without improvement: 6
# Epoch 9/250, Batch 1/3, Loss: 0.18940946459770203
# Validation Loss after Epoch 9: 1.8683744668960571
# Validation Loss after Epoch 9: 1.8683744668960571, Epochs without improvement: 7
# Epoch 10/250, Batch 1/3, Loss: 0.17586836218833923
# Validation Loss after Epoch 10: 2.0267834663391113
# Validation Loss after Epoch 10: 2.0267834663391113, Epochs without improvement: 8
# Epoch 11/250, Batch 1/3, Loss: 0.16365240514278412
# Validation Loss after Epoch 11: 2.059288501739502
# Validation Loss after Epoch 11: 2.059288501739502, Epochs without improvement: 9
# Epoch 12/250, Batch 1/3, Loss: 0.15168079733848572
# Validation Loss after Epoch 12: 1.931640863418579
# Validation Loss after Epoch 12: 1.931640863418579, Epochs without improvement: 10
# Early stopping triggered
# Subset size 100 - Test Loss: 1.8885, Test Accuracy: 44.87%, Average Dice Score: 0.2410
# Training on subset size: 250
# Epoch 1/250, Batch 1/6, Loss: 1.1575751304626465
# Validation Loss after Epoch 1: 1.0500352382659912
# Validation Loss after Epoch 1: 1.0500352382659912, Epochs without improvement: 0
# Epoch 2/250, Batch 1/6, Loss: 0.3256136178970337
# Validation Loss after Epoch 2: 1.1713070273399353
# Validation Loss after Epoch 2: 1.1713070273399353, Epochs without improvement: 1
# Epoch 3/250, Batch 1/6, Loss: 0.25201064348220825
# Validation Loss after Epoch 3: 1.3705856800079346
# Validation Loss after Epoch 3: 1.3705856800079346, Epochs without improvement: 2
# Epoch 4/250, Batch 1/6, Loss: 0.21388700604438782
# Validation Loss after Epoch 4: 1.6652814149856567
# Validation Loss after Epoch 4: 1.6652814149856567, Epochs without improvement: 3
# Epoch 5/250, Batch 1/6, Loss: 0.1813725233078003
# Validation Loss after Epoch 5: 1.4500880241394043
# Validation Loss after Epoch 5: 1.4500880241394043, Epochs without improvement: 4
# Epoch 6/250, Batch 1/6, Loss: 0.1595933735370636
# Validation Loss after Epoch 6: 1.4085769057273865
# Validation Loss after Epoch 6: 1.4085769057273865, Epochs without improvement: 5
# Epoch 7/250, Batch 1/6, Loss: 0.14413954317569733
# Validation Loss after Epoch 7: 1.2052818536758423
# Validation Loss after Epoch 7: 1.2052818536758423, Epochs without improvement: 6
# Epoch 8/250, Batch 1/6, Loss: 0.12874487042427063
# Validation Loss after Epoch 8: 1.0266706347465515
# Validation Loss after Epoch 8: 1.0266706347465515, Epochs without improvement: 0
# Epoch 9/250, Batch 1/6, Loss: 0.11662609875202179
# Validation Loss after Epoch 9: 0.6375105679035187
# Validation Loss after Epoch 9: 0.6375105679035187, Epochs without improvement: 0
# Epoch 10/250, Batch 1/6, Loss: 0.10779453814029694
# Validation Loss after Epoch 10: 0.35325220227241516
# Validation Loss after Epoch 10: 0.35325220227241516, Epochs without improvement: 0
# Epoch 11/250, Batch 1/6, Loss: 0.1016034260392189
# Validation Loss after Epoch 11: 0.298141285777092
# Validation Loss after Epoch 11: 0.298141285777092, Epochs without improvement: 0
# Epoch 12/250, Batch 1/6, Loss: 0.09216544777154922
# Validation Loss after Epoch 12: 0.2006472498178482
# Validation Loss after Epoch 12: 0.2006472498178482, Epochs without improvement: 0
# Epoch 13/250, Batch 1/6, Loss: 0.08706089854240417
# Validation Loss after Epoch 13: 0.1414307951927185
# Validation Loss after Epoch 13: 0.1414307951927185, Epochs without improvement: 0
# Epoch 14/250, Batch 1/6, Loss: 0.07751742750406265
# Validation Loss after Epoch 14: 0.17696139961481094
# Validation Loss after Epoch 14: 0.17696139961481094, Epochs without improvement: 1
# Epoch 15/250, Batch 1/6, Loss: 0.0793982446193695
# Validation Loss after Epoch 15: 0.12324531003832817
# Validation Loss after Epoch 15: 0.12324531003832817, Epochs without improvement: 0
# Epoch 16/250, Batch 1/6, Loss: 0.07310444861650467
# Validation Loss after Epoch 16: 0.11595548316836357
# Validation Loss after Epoch 16: 0.11595548316836357, Epochs without improvement: 0
# Epoch 17/250, Batch 1/6, Loss: 0.06745845824480057
# Validation Loss after Epoch 17: 0.10249076411128044
# Validation Loss after Epoch 17: 0.10249076411128044, Epochs without improvement: 0
# Epoch 18/250, Batch 1/6, Loss: 0.06201011314988136
# Validation Loss after Epoch 18: 0.09329802542924881
# Validation Loss after Epoch 18: 0.09329802542924881, Epochs without improvement: 0
# Epoch 19/250, Batch 1/6, Loss: 0.06002267822623253
# Validation Loss after Epoch 19: 0.09133012965321541
# Validation Loss after Epoch 19: 0.09133012965321541, Epochs without improvement: 0
# Epoch 20/250, Batch 1/6, Loss: 0.055455099791288376
# Validation Loss after Epoch 20: 0.08316783234477043
# Validation Loss after Epoch 20: 0.08316783234477043, Epochs without improvement: 0
# Epoch 21/250, Batch 1/6, Loss: 0.05463587865233421
# Validation Loss after Epoch 21: 0.07924697175621986
# Validation Loss after Epoch 21: 0.07924697175621986, Epochs without improvement: 0
# Epoch 22/250, Batch 1/6, Loss: 0.05187396705150604
# Validation Loss after Epoch 22: 0.07214589044451714
# Validation Loss after Epoch 22: 0.07214589044451714, Epochs without improvement: 0
# Epoch 23/250, Batch 1/6, Loss: 0.049377936869859695
# Validation Loss after Epoch 23: 0.07178832963109016
# Validation Loss after Epoch 23: 0.07178832963109016, Epochs without improvement: 0
# Epoch 24/250, Batch 1/6, Loss: 0.04837982729077339
# Validation Loss after Epoch 24: 0.07468514516949654
# Validation Loss after Epoch 24: 0.07468514516949654, Epochs without improvement: 1
# Epoch 25/250, Batch 1/6, Loss: 0.04658721014857292
# Validation Loss after Epoch 25: 0.07042290642857552
# Validation Loss after Epoch 25: 0.07042290642857552, Epochs without improvement: 0
# Epoch 26/250, Batch 1/6, Loss: 0.043586522340774536
# Validation Loss after Epoch 26: 0.07490313425660133
# Validation Loss after Epoch 26: 0.07490313425660133, Epochs without improvement: 1
# Epoch 27/250, Batch 1/6, Loss: 0.04150915890932083
# Validation Loss after Epoch 27: 0.06744849681854248
# Validation Loss after Epoch 27: 0.06744849681854248, Epochs without improvement: 0
# Epoch 28/250, Batch 1/6, Loss: 0.0395057238638401
# Validation Loss after Epoch 28: 0.07328495383262634
# Validation Loss after Epoch 28: 0.07328495383262634, Epochs without improvement: 1
# Epoch 29/250, Batch 1/6, Loss: 0.038151953369379044
# Validation Loss after Epoch 29: 0.06421049684286118
# Validation Loss after Epoch 29: 0.06421049684286118, Epochs without improvement: 0
# Epoch 30/250, Batch 1/6, Loss: 0.03780249506235123
# Validation Loss after Epoch 30: 0.07504314929246902
# Validation Loss after Epoch 30: 0.07504314929246902, Epochs without improvement: 1
# Epoch 31/250, Batch 1/6, Loss: 0.03660717234015465
# Validation Loss after Epoch 31: 0.07210702821612358
# Validation Loss after Epoch 31: 0.07210702821612358, Epochs without improvement: 2
# Epoch 32/250, Batch 1/6, Loss: 0.03643963485956192
# Validation Loss after Epoch 32: 0.06821130588650703
# Validation Loss after Epoch 32: 0.06821130588650703, Epochs without improvement: 3
# Epoch 33/250, Batch 1/6, Loss: 0.03303680196404457
# Validation Loss after Epoch 33: 0.06468668393790722
# Validation Loss after Epoch 33: 0.06468668393790722, Epochs without improvement: 4
# Epoch 34/250, Batch 1/6, Loss: 0.03321724012494087
# Validation Loss after Epoch 34: 0.0668425653129816
# Validation Loss after Epoch 34: 0.0668425653129816, Epochs without improvement: 5
# Epoch 35/250, Batch 1/6, Loss: 0.03394114598631859
# Validation Loss after Epoch 35: 0.06266432255506516
# Validation Loss after Epoch 35: 0.06266432255506516, Epochs without improvement: 0
# Epoch 36/250, Batch 1/6, Loss: 0.030359521508216858
# Validation Loss after Epoch 36: 0.06415863148868084
# Validation Loss after Epoch 36: 0.06415863148868084, Epochs without improvement: 1
# Epoch 37/250, Batch 1/6, Loss: 0.028818409889936447
# Validation Loss after Epoch 37: 0.05799291096627712
# Validation Loss after Epoch 37: 0.05799291096627712, Epochs without improvement: 0
# Epoch 38/250, Batch 1/6, Loss: 0.029390092939138412
# Validation Loss after Epoch 38: 0.05693703889846802
# Validation Loss after Epoch 38: 0.05693703889846802, Epochs without improvement: 0
# Epoch 39/250, Batch 1/6, Loss: 0.02965378761291504
# Validation Loss after Epoch 39: 0.049926403909921646
# Validation Loss after Epoch 39: 0.049926403909921646, Epochs without improvement: 0
# Epoch 40/250, Batch 1/6, Loss: 0.027209525927901268
# Validation Loss after Epoch 40: 0.060024626553058624
# Validation Loss after Epoch 40: 0.060024626553058624, Epochs without improvement: 1
# Epoch 41/250, Batch 1/6, Loss: 0.026352711021900177
# Validation Loss after Epoch 41: 0.05850323662161827
# Validation Loss after Epoch 41: 0.05850323662161827, Epochs without improvement: 2
# Epoch 42/250, Batch 1/6, Loss: 0.025602281093597412
# Validation Loss after Epoch 42: 0.05675085447728634
# Validation Loss after Epoch 42: 0.05675085447728634, Epochs without improvement: 3
# Epoch 43/250, Batch 1/6, Loss: 0.025903137400746346
# Validation Loss after Epoch 43: 0.052517352625727654
# Validation Loss after Epoch 43: 0.052517352625727654, Epochs without improvement: 4
# Epoch 44/250, Batch 1/6, Loss: 0.025786949321627617
# Validation Loss after Epoch 44: 0.04727715067565441
# Validation Loss after Epoch 44: 0.04727715067565441, Epochs without improvement: 0
# Epoch 45/250, Batch 1/6, Loss: 0.02576589770615101
# Validation Loss after Epoch 45: 0.047276876866817474
# Validation Loss after Epoch 45: 0.047276876866817474, Epochs without improvement: 0
# Epoch 46/250, Batch 1/6, Loss: 0.023301245644688606
# Validation Loss after Epoch 46: 0.047146519646048546
# Validation Loss after Epoch 46: 0.047146519646048546, Epochs without improvement: 0
# Epoch 47/250, Batch 1/6, Loss: 0.024594129994511604
# Validation Loss after Epoch 47: 0.04752010107040405
# Validation Loss after Epoch 47: 0.04752010107040405, Epochs without improvement: 1
# Epoch 48/250, Batch 1/6, Loss: 0.023700162768363953
# Validation Loss after Epoch 48: 0.05062422528862953
# Validation Loss after Epoch 48: 0.05062422528862953, Epochs without improvement: 2
# Epoch 49/250, Batch 1/6, Loss: 0.023579508066177368
# Validation Loss after Epoch 49: 0.048327477648854256
# Validation Loss after Epoch 49: 0.048327477648854256, Epochs without improvement: 3
# Epoch 50/250, Batch 1/6, Loss: 0.021876154467463493
# Validation Loss after Epoch 50: 0.05623798817396164
# Validation Loss after Epoch 50: 0.05623798817396164, Epochs without improvement: 4
# Epoch 51/250, Batch 1/6, Loss: 0.022858954966068268
# Validation Loss after Epoch 51: 0.04734216071665287
# Validation Loss after Epoch 51: 0.04734216071665287, Epochs without improvement: 5
# Epoch 52/250, Batch 1/6, Loss: 0.02289060689508915
# Validation Loss after Epoch 52: 0.05076128616929054
# Validation Loss after Epoch 52: 0.05076128616929054, Epochs without improvement: 6
# Epoch 53/250, Batch 1/6, Loss: 0.022034496068954468
# Validation Loss after Epoch 53: 0.04659792594611645
# Validation Loss after Epoch 53: 0.04659792594611645, Epochs without improvement: 0
# Epoch 54/250, Batch 1/6, Loss: 0.020885253325104713
# Validation Loss after Epoch 54: 0.04918690398335457
# Validation Loss after Epoch 54: 0.04918690398335457, Epochs without improvement: 1
# Epoch 55/250, Batch 1/6, Loss: 0.020695015788078308
# Validation Loss after Epoch 55: 0.04824987053871155
# Validation Loss after Epoch 55: 0.04824987053871155, Epochs without improvement: 2
# Epoch 56/250, Batch 1/6, Loss: 0.019107230007648468
# Validation Loss after Epoch 56: 0.050609420984983444
# Validation Loss after Epoch 56: 0.050609420984983444, Epochs without improvement: 3
# Epoch 57/250, Batch 1/6, Loss: 0.019336383789777756
# Validation Loss after Epoch 57: 0.04870985448360443
# Validation Loss after Epoch 57: 0.04870985448360443, Epochs without improvement: 4
# Epoch 58/250, Batch 1/6, Loss: 0.02034333348274231
# Validation Loss after Epoch 58: 0.04841038025915623
# Validation Loss after Epoch 58: 0.04841038025915623, Epochs without improvement: 5
# Epoch 59/250, Batch 1/6, Loss: 0.018722061067819595
# Validation Loss after Epoch 59: 0.04901552572846413
# Validation Loss after Epoch 59: 0.04901552572846413, Epochs without improvement: 6
# Epoch 60/250, Batch 1/6, Loss: 0.018162347376346588
# Validation Loss after Epoch 60: 0.04655632935464382
# Validation Loss after Epoch 60: 0.04655632935464382, Epochs without improvement: 0
# Epoch 61/250, Batch 1/6, Loss: 0.01776287518441677
# Validation Loss after Epoch 61: 0.046184077858924866
# Validation Loss after Epoch 61: 0.046184077858924866, Epochs without improvement: 0
# Epoch 62/250, Batch 1/6, Loss: 0.01756436750292778
# Validation Loss after Epoch 62: 0.05015787295997143
# Validation Loss after Epoch 62: 0.05015787295997143, Epochs without improvement: 1
# Epoch 63/250, Batch 1/6, Loss: 0.0170384980738163
# Validation Loss after Epoch 63: 0.05072735249996185
# Validation Loss after Epoch 63: 0.05072735249996185, Epochs without improvement: 2
# Epoch 64/250, Batch 1/6, Loss: 0.01673443615436554
# Validation Loss after Epoch 64: 0.047814929857850075
# Validation Loss after Epoch 64: 0.047814929857850075, Epochs without improvement: 3
# Epoch 65/250, Batch 1/6, Loss: 0.01663876697421074
# Validation Loss after Epoch 65: 0.0476364828646183
# Validation Loss after Epoch 65: 0.0476364828646183, Epochs without improvement: 4
# Epoch 66/250, Batch 1/6, Loss: 0.016785170882940292
# Validation Loss after Epoch 66: 0.04827564023435116
# Validation Loss after Epoch 66: 0.04827564023435116, Epochs without improvement: 5
# Epoch 67/250, Batch 1/6, Loss: 0.01587575301527977
# Validation Loss after Epoch 67: 0.05586394481360912
# Validation Loss after Epoch 67: 0.05586394481360912, Epochs without improvement: 6
# Epoch 68/250, Batch 1/6, Loss: 0.016154753044247627
# Validation Loss after Epoch 68: 0.04738541506230831
# Validation Loss after Epoch 68: 0.04738541506230831, Epochs without improvement: 7
# Epoch 69/250, Batch 1/6, Loss: 0.01668963022530079
# Validation Loss after Epoch 69: 0.05095825344324112
# Validation Loss after Epoch 69: 0.05095825344324112, Epochs without improvement: 8
# Epoch 70/250, Batch 1/6, Loss: 0.016497772186994553
# Validation Loss after Epoch 70: 0.05066315270960331
# Validation Loss after Epoch 70: 0.05066315270960331, Epochs without improvement: 9
# Epoch 71/250, Batch 1/6, Loss: 0.014247649349272251
# Validation Loss after Epoch 71: 0.048569461330771446
# Validation Loss after Epoch 71: 0.048569461330771446, Epochs without improvement: 10
# Early stopping triggered
# Subset size 250 - Test Loss: 0.0583, Test Accuracy: 97.95%, Average Dice Score: 0.9787
# Training on subset size: 500
# Epoch 1/250, Batch 1/11, Loss: 1.1646617650985718
# Epoch 1/250, Batch 11/11, Loss: 0.2757614552974701
# Validation Loss after Epoch 1: 1.0824445883433025
# Validation Loss after Epoch 1: 1.0824445883433025, Epochs without improvement: 0
# Epoch 2/250, Batch 1/11, Loss: 0.26549869775772095
# Epoch 2/250, Batch 11/11, Loss: 0.19959473609924316
# Validation Loss after Epoch 2: 1.3536893526713054
# Validation Loss after Epoch 2: 1.3536893526713054, Epochs without improvement: 1
# Epoch 3/250, Batch 1/11, Loss: 0.19235356152057648
# Epoch 3/250, Batch 11/11, Loss: 0.1558467000722885
# Validation Loss after Epoch 3: 1.2629602352778118
# Validation Loss after Epoch 3: 1.2629602352778118, Epochs without improvement: 2
# Epoch 4/250, Batch 1/11, Loss: 0.15355265140533447
# Epoch 4/250, Batch 11/11, Loss: 0.13003608584403992
# Validation Loss after Epoch 4: 0.9393111069997152
# Validation Loss after Epoch 4: 0.9393111069997152, Epochs without improvement: 0
# Epoch 5/250, Batch 1/11, Loss: 0.13067379593849182
# Epoch 5/250, Batch 11/11, Loss: 0.10909181088209152
# Validation Loss after Epoch 5: 0.33564717570940655
# Validation Loss after Epoch 5: 0.33564717570940655, Epochs without improvement: 0
# Epoch 6/250, Batch 1/11, Loss: 0.11188440769910812
# Epoch 6/250, Batch 11/11, Loss: 0.09879579395055771
# Validation Loss after Epoch 6: 0.18654850125312805
# Validation Loss after Epoch 6: 0.18654850125312805, Epochs without improvement: 0
# Epoch 7/250, Batch 1/11, Loss: 0.09461335092782974
# Epoch 7/250, Batch 11/11, Loss: 0.087203748524189
# Validation Loss after Epoch 7: 0.10543044159809749
# Validation Loss after Epoch 7: 0.10543044159809749, Epochs without improvement: 0
# Epoch 8/250, Batch 1/11, Loss: 0.08445275574922562
# Epoch 8/250, Batch 11/11, Loss: 0.07970903068780899
# Validation Loss after Epoch 8: 0.08074060082435608
# Validation Loss after Epoch 8: 0.08074060082435608, Epochs without improvement: 0
# Epoch 9/250, Batch 1/11, Loss: 0.07544226199388504
# Epoch 9/250, Batch 11/11, Loss: 0.07186589390039444
# Validation Loss after Epoch 9: 0.07511862864096959
# Validation Loss after Epoch 9: 0.07511862864096959, Epochs without improvement: 0
# Epoch 10/250, Batch 1/11, Loss: 0.06958996504545212
# Epoch 10/250, Batch 11/11, Loss: 0.06748978793621063
# Validation Loss after Epoch 10: 0.06910248349110286
# Validation Loss after Epoch 10: 0.06910248349110286, Epochs without improvement: 0
# Epoch 11/250, Batch 1/11, Loss: 0.06426170468330383
# Epoch 11/250, Batch 11/11, Loss: 0.06318188458681107
# Validation Loss after Epoch 11: 0.06527134279410045
# Validation Loss after Epoch 11: 0.06527134279410045, Epochs without improvement: 0
# Epoch 12/250, Batch 1/11, Loss: 0.06060175597667694
# Epoch 12/250, Batch 11/11, Loss: 0.05831577256321907
# Validation Loss after Epoch 12: 0.067707692583402
# Validation Loss after Epoch 12: 0.067707692583402, Epochs without improvement: 1
# Epoch 13/250, Batch 1/11, Loss: 0.05497071146965027
# Epoch 13/250, Batch 11/11, Loss: 0.0534098744392395
# Validation Loss after Epoch 13: 0.05742441117763519
# Validation Loss after Epoch 13: 0.05742441117763519, Epochs without improvement: 0
# Epoch 14/250, Batch 1/11, Loss: 0.053004052489995956
# Epoch 14/250, Batch 11/11, Loss: 0.05216414853930473
# Validation Loss after Epoch 14: 0.056168091793855034
# Validation Loss after Epoch 14: 0.056168091793855034, Epochs without improvement: 0
# Epoch 15/250, Batch 1/11, Loss: 0.050121814012527466
# Epoch 15/250, Batch 11/11, Loss: 0.049650680273771286
# Validation Loss after Epoch 15: 0.0532542330523332
# Validation Loss after Epoch 15: 0.0532542330523332, Epochs without improvement: 0
# Epoch 16/250, Batch 1/11, Loss: 0.048006728291511536
# Epoch 16/250, Batch 11/11, Loss: 0.047578271478414536
# Validation Loss after Epoch 16: 0.05303511768579483
# Validation Loss after Epoch 16: 0.05303511768579483, Epochs without improvement: 0
# Epoch 17/250, Batch 1/11, Loss: 0.045338016003370285
# Epoch 17/250, Batch 11/11, Loss: 0.04517631232738495
# Validation Loss after Epoch 17: 0.04633026570081711
# Validation Loss after Epoch 17: 0.04633026570081711, Epochs without improvement: 0
# Epoch 18/250, Batch 1/11, Loss: 0.04308173432946205
# Epoch 18/250, Batch 11/11, Loss: 0.04539914429187775
# Validation Loss after Epoch 18: 0.04485706736644109
# Validation Loss after Epoch 18: 0.04485706736644109, Epochs without improvement: 0
# Epoch 19/250, Batch 1/11, Loss: 0.04019948095083237
# Epoch 19/250, Batch 11/11, Loss: 0.04388156905770302
# Validation Loss after Epoch 19: 0.04680110141634941
# Validation Loss after Epoch 19: 0.04680110141634941, Epochs without improvement: 1
# Epoch 20/250, Batch 1/11, Loss: 0.039873845875263214
# Epoch 20/250, Batch 11/11, Loss: 0.04018760845065117
# Validation Loss after Epoch 20: 0.04551931843161583
# Validation Loss after Epoch 20: 0.04551931843161583, Epochs without improvement: 2
# Epoch 21/250, Batch 1/11, Loss: 0.038687266409397125
# Epoch 21/250, Batch 11/11, Loss: 0.040851280093193054
# Validation Loss after Epoch 21: 0.042779634396235146
# Validation Loss after Epoch 21: 0.042779634396235146, Epochs without improvement: 0
# Epoch 22/250, Batch 1/11, Loss: 0.03847196698188782
# Epoch 22/250, Batch 11/11, Loss: 0.037731364369392395
# Validation Loss after Epoch 22: 0.04402980829278628
# Validation Loss after Epoch 22: 0.04402980829278628, Epochs without improvement: 1
# Epoch 23/250, Batch 1/11, Loss: 0.03601713478565216
# Epoch 23/250, Batch 11/11, Loss: 0.035702187567949295
# Validation Loss after Epoch 23: 0.04846335699160894
# Validation Loss after Epoch 23: 0.04846335699160894, Epochs without improvement: 2
# Epoch 24/250, Batch 1/11, Loss: 0.03615373745560646
# Epoch 24/250, Batch 11/11, Loss: 0.03716731071472168
# Validation Loss after Epoch 24: 0.044630693892637886
# Validation Loss after Epoch 24: 0.044630693892637886, Epochs without improvement: 3
# Epoch 25/250, Batch 1/11, Loss: 0.03486044704914093
# Epoch 25/250, Batch 11/11, Loss: 0.03523850068449974
# Validation Loss after Epoch 25: 0.04554570217927297
# Validation Loss after Epoch 25: 0.04554570217927297, Epochs without improvement: 4
# Epoch 26/250, Batch 1/11, Loss: 0.03297833353281021
# Epoch 26/250, Batch 11/11, Loss: 0.034883759915828705
# Validation Loss after Epoch 26: 0.045433701326449714
# Validation Loss after Epoch 26: 0.045433701326449714, Epochs without improvement: 5
# Epoch 27/250, Batch 1/11, Loss: 0.03252978250384331
# Epoch 27/250, Batch 11/11, Loss: 0.03419087454676628
# Validation Loss after Epoch 27: 0.04713149989644686
# Validation Loss after Epoch 27: 0.04713149989644686, Epochs without improvement: 6
# Epoch 28/250, Batch 1/11, Loss: 0.031895820051431656
# Epoch 28/250, Batch 11/11, Loss: 0.03372632712125778
# Validation Loss after Epoch 28: 0.04220523685216904
# Validation Loss after Epoch 28: 0.04220523685216904, Epochs without improvement: 0
# Epoch 29/250, Batch 1/11, Loss: 0.030518818646669388
# Epoch 29/250, Batch 11/11, Loss: 0.03189323469996452
# Validation Loss after Epoch 29: 0.046216984589894615
# Validation Loss after Epoch 29: 0.046216984589894615, Epochs without improvement: 1
# Epoch 30/250, Batch 1/11, Loss: 0.03000967763364315
# Epoch 30/250, Batch 11/11, Loss: 0.031820300966501236
# Validation Loss after Epoch 30: 0.040901198983192444
# Validation Loss after Epoch 30: 0.040901198983192444, Epochs without improvement: 0
# Epoch 31/250, Batch 1/11, Loss: 0.028444675728678703
# Epoch 31/250, Batch 11/11, Loss: 0.0325472429394722
# Validation Loss after Epoch 31: 0.04664109771450361
# Validation Loss after Epoch 31: 0.04664109771450361, Epochs without improvement: 1
# Epoch 32/250, Batch 1/11, Loss: 0.028882917016744614
# Epoch 32/250, Batch 11/11, Loss: 0.031183987855911255
# Validation Loss after Epoch 32: 0.045312135169903435
# Validation Loss after Epoch 32: 0.045312135169903435, Epochs without improvement: 2
# Epoch 33/250, Batch 1/11, Loss: 0.02827470935881138
# Epoch 33/250, Batch 11/11, Loss: 0.02958604507148266
# Validation Loss after Epoch 33: 0.041778753201166786
# Validation Loss after Epoch 33: 0.041778753201166786, Epochs without improvement: 3
# Epoch 34/250, Batch 1/11, Loss: 0.027437692508101463
# Epoch 34/250, Batch 11/11, Loss: 0.028722254559397697
# Validation Loss after Epoch 34: 0.04383213445544243
# Validation Loss after Epoch 34: 0.04383213445544243, Epochs without improvement: 4
# Epoch 35/250, Batch 1/11, Loss: 0.026867028325796127
# Epoch 35/250, Batch 11/11, Loss: 0.029851607978343964
# Validation Loss after Epoch 35: 0.04019156967600187
# Validation Loss after Epoch 35: 0.04019156967600187, Epochs without improvement: 0
# Epoch 36/250, Batch 1/11, Loss: 0.026931658387184143
# Epoch 36/250, Batch 11/11, Loss: 0.027676325291395187
# Validation Loss after Epoch 36: 0.04656178752581278
# Validation Loss after Epoch 36: 0.04656178752581278, Epochs without improvement: 1
# Epoch 37/250, Batch 1/11, Loss: 0.027166632935404778
# Epoch 37/250, Batch 11/11, Loss: 0.02663850598037243
# Validation Loss after Epoch 37: 0.04078465327620506
# Validation Loss after Epoch 37: 0.04078465327620506, Epochs without improvement: 2
# Epoch 38/250, Batch 1/11, Loss: 0.024804942309856415
# Epoch 38/250, Batch 11/11, Loss: 0.027651933953166008
# Validation Loss after Epoch 38: 0.037911331901947655
# Validation Loss after Epoch 38: 0.037911331901947655, Epochs without improvement: 0
# Epoch 39/250, Batch 1/11, Loss: 0.024117810651659966
# Epoch 39/250, Batch 11/11, Loss: 0.024963432922959328
# Validation Loss after Epoch 39: 0.04537692293524742
# Validation Loss after Epoch 39: 0.04537692293524742, Epochs without improvement: 1
# Epoch 40/250, Batch 1/11, Loss: 0.024472244083881378
# Epoch 40/250, Batch 11/11, Loss: 0.027442822232842445
# Validation Loss after Epoch 40: 0.03915796925624212
# Validation Loss after Epoch 40: 0.03915796925624212, Epochs without improvement: 2
# Epoch 41/250, Batch 1/11, Loss: 0.024380967020988464
# Epoch 41/250, Batch 11/11, Loss: 0.025820812210440636
# Validation Loss after Epoch 41: 0.04822875062624613
# Validation Loss after Epoch 41: 0.04822875062624613, Epochs without improvement: 3
# Epoch 42/250, Batch 1/11, Loss: 0.023807670921087265
# Epoch 42/250, Batch 11/11, Loss: 0.025558536872267723
# Validation Loss after Epoch 42: 0.04118570933739344
# Validation Loss after Epoch 42: 0.04118570933739344, Epochs without improvement: 4
# Epoch 43/250, Batch 1/11, Loss: 0.022131826728582382
# Epoch 43/250, Batch 11/11, Loss: 0.025295739993453026
# Validation Loss after Epoch 43: 0.04374740272760391
# Validation Loss after Epoch 43: 0.04374740272760391, Epochs without improvement: 5
# Epoch 44/250, Batch 1/11, Loss: 0.021847695112228394
# Epoch 44/250, Batch 11/11, Loss: 0.024649113416671753
# Validation Loss after Epoch 44: 0.045433624337116875
# Validation Loss after Epoch 44: 0.045433624337116875, Epochs without improvement: 6
# Epoch 45/250, Batch 1/11, Loss: 0.021681321784853935
# Epoch 45/250, Batch 11/11, Loss: 0.023266900330781937
# Validation Loss after Epoch 45: 0.038093842566013336
# Validation Loss after Epoch 45: 0.038093842566013336, Epochs without improvement: 7
# Epoch 46/250, Batch 1/11, Loss: 0.021963588893413544
# Epoch 46/250, Batch 11/11, Loss: 0.023295314982533455
# Validation Loss after Epoch 46: 0.03856231768925985
# Validation Loss after Epoch 46: 0.03856231768925985, Epochs without improvement: 8
# Epoch 47/250, Batch 1/11, Loss: 0.0222620889544487
# Epoch 47/250, Batch 11/11, Loss: 0.025386905297636986
# Validation Loss after Epoch 47: 0.047192358722289406
# Validation Loss after Epoch 47: 0.047192358722289406, Epochs without improvement: 9
# Epoch 48/250, Batch 1/11, Loss: 0.020606806501746178
# Epoch 48/250, Batch 11/11, Loss: 0.023355985060334206
# Validation Loss after Epoch 48: 0.03826106463869413
# Validation Loss after Epoch 48: 0.03826106463869413, Epochs without improvement: 10
# Early stopping triggered
# Subset size 500 - Test Loss: 0.0368, Test Accuracy: 98.47%, Average Dice Score: 0.9846

# %%
torch.save(model.state_dict(), '128x128smaller_subsets_with_Early_Stoppage.pth')

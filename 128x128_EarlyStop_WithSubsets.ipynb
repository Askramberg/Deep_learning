# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import torch
import torch.nn as nn
from torchvision import models
from torch.nn.functional import relu
import torch.nn.functional as F


from torch.utils.data import Dataset
from PIL import Image
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, image_paths, label_paths):
        self.image_paths = image_paths
        self.label_paths = label_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load the image using PIL
        with Image.open(self.image_paths[idx]) as img:
            np_image = np.array(img, dtype=np.float32)

        # Normalize the image
        normalized_image = np_image / 65535.0  # Assuming 16-bit images

        # Load and process the label data using PIL
        with Image.open(self.label_paths[idx]) as label_img:
            label_array = np.array(label_img, dtype=np.float32)

        grayscale_to_class_mapping = {0: 0, 128: 1, 255: 2} # Maps gray-levels to class

        # Map grayscale values to class labels
        mapped_labels = np.copy(label_array)
        for grayscale_value, class_id in grayscale_to_class_mapping.items():
            mapped_labels[label_array == grayscale_value] = class_id

        # Convert to PyTorch tensors
        image_tensor = torch.from_numpy(normalized_image).unsqueeze(0) # Add channel dimension
        label_tensor = torch.from_numpy(mapped_labels).long() # Ensure label tensor is long type

        return image_tensor, label_tensor

# %%
### Label images ###
# white class - 255 nickel
# gray class - 128 ysz
# black class - 0 pores

class UNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()

        # Define a helper function for creating a block
        def conv_block(in_channels, out_channels):
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
                nn.Dropout(p=0.1)
            )

        # Encoder
        self.e11 = conv_block(1, 64)
        self.e12 = conv_block(64, 64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e21 = conv_block(64, 128)
        self.e22 = conv_block(128, 128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e31 = conv_block(128, 256)
        self.e32 = conv_block(256, 256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e41 = conv_block(256, 512)
        self.e42 = conv_block(512, 512)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.e51 = conv_block(512, 1024)
        self.e52 = conv_block(1024, 1024)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.d11 = conv_block(1024, 512)
        self.d12 = conv_block(512, 512)

        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.d21 = conv_block(512, 256)
        self.d22 = conv_block(256, 256)

        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.d31 = conv_block(256, 128)
        self.d32 = conv_block(128, 128)

        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.d41 = conv_block(128, 64)
        self.d42 = conv_block(64, 64)

        # Output layer
        self.outconv = nn.Conv2d(64, n_class, kernel_size=1)

    def forward(self, x):
        # Encoder
        xe11 = self.e11(x)
        xe12 = self.e12(xe11)
        xp1 = self.pool1(xe12)

        xe21 = self.e21(xp1)
        xe22 = self.e22(xe21)
        xp2 = self.pool2(xe22)

        xe31 = self.e31(xp2)
        xe32 = self.e32(xe31)
        xp3 = self.pool3(xe32)

        xe41 = self.e41(xp3)
        xe42 = self.e42(xe41)
        xp4 = self.pool4(xe42)

        xe51 = self.e51(xp4)
        xe52 = self.e52(xe51)

        # Decoder
        xu1 = self.upconv1(xe52)
        xu11 = torch.cat([xu1, xe42], dim=1)
        xd11 = self.d11(xu11)
        xd12 = self.d12(xd11)

        xu2 = self.upconv2(xd12)
        xu22 = torch.cat([xu2, xe32], dim=1)
        xd21 = self.d21(xu22)
        xd22 = self.d22(xd21)

        xu3 = self.upconv3(xd22)
        xu33 = torch.cat([xu3, xe22], dim=1)
        xd31 = self.d31(xu33)
        xd32 = self.d32(xd31)

        xu4 = self.upconv4(xd32)
        xu44 = torch.cat([xu4, xe12], dim=1)
        xd41 = self.d41(xu44)
        xd42 = self.d42(xd41)

        # Output layer
        out = self.outconv(xd42)

        return out

# %%
from torch.utils.data import DataLoader, random_split
from torch import optim
import torch
import os
import matplotlib.pyplot as plt

def dice_coefficient(predicted, target, num_classes):
    dice_scores = []  # To store dice coefficient for each class

    # Convert predictions and targets to one-hot encoded form
    predicted_one_hot = F.one_hot(predicted, num_classes).permute(0, 3, 1, 2).float()
    target_one_hot = F.one_hot(target, num_classes).permute(0, 3, 1, 2).float()

    # Calculate Dice coefficient for each class
    for class_index in range(num_classes):
        intersection = (predicted_one_hot[:, class_index, :, :] * target_one_hot[:, class_index, :, :]).sum()
        union = predicted_one_hot[:, class_index, :, :].sum() + target_one_hot[:, class_index, :, :].sum()
        dice_score = (2 * intersection + 1e-6) / (union + 1e-6)  # Adding a small epsilon to avoid division by zero
        dice_scores.append(dice_score)

    # Average Dice score across all classes
    avg_dice_score = sum(dice_scores) / len(dice_scores)
    return avg_dice_score.item()  # Return the value as a Python scalar

def get_image_paths(data_dir, label_dir):
    data_paths = [os.path.join(data_dir, img) for img in sorted(os.listdir(data_dir))]
    label_paths = [os.path.join(label_dir, lbl) for lbl in sorted(os.listdir(label_dir))]
    return data_paths, label_paths

def create_subsets(dataset, subset_sizes):
    subsets = {}
    for size in subset_sizes:
        if size == len(dataset):
            subsets[size] = dataset  # Use the full dataset
        else:
            subset, _ = random_split(dataset, [size, len(dataset) - size])
            subsets[size] = subset
    return subsets

def plot_predictions(images, actuals, predicted):
    plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
    for i in range(len(images)):
        # Rescale the images from [0, 1] to [0, 65535]
        image = images[i].squeeze() * 65535

        # Contrast stretching the original image for visualization (directly doing 16bit to 8bit got fucked)
        vmin, vmax = image.min(), image.max()
        image = (image - vmin) / (vmax - vmin)  # Scale pixel values to 0-1 range
        image = (image * 255).to(torch.uint8).cpu().numpy()  # Scale up to 0-255 range and convert to 8-bit

        # Display the original image
        plt.subplot(1, len(images)*3, i*3+1)
        plt.imshow(image, cmap='gray')
        plt.title(f'Original Image')
        plt.axis('off')

        # Display the actual label image
        actual = actuals[i].squeeze()  # Assuming actuals is a batch of label images
        plt.subplot(1, len(images)*3, i*3+2)
        plt.imshow(actual, cmap='gray')
        plt.title(f'Actual Label')
        plt.axis('off')

        # Display the predicted label image
        pred = predicted[i].squeeze()  # Assuming predicted is a batch of label images
        plt.subplot(1, len(images)*3, i*3+3)
        plt.imshow(pred, cmap='gray')
        plt.title(f'Predicted Label')
        plt.axis('off')

    plt.show()

# %%
# Define your dataset paths
data_dir = '/content/gdrive/MyDrive/training_dataset/data_resize128/'
label_dir = '/content/gdrive/MyDrive/training_dataset/label_resize128/'

# Get image paths and create the full dataset
image_paths, label_paths = get_image_paths(data_dir, label_dir)
dataset = CustomDataset(image_paths=image_paths, label_paths=label_paths)

# Define subset sizes including the full dataset size
subset_size = [100, 250, len(dataset)]  # Add the full dataset size

# Create subsets
dataset_subsets = create_subsets(dataset, subset_size)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")

# Training configurations
learning_rate = 0.001
num_epochs = 250  # Adjust as needed

# Early stopping parameters
patience = 10  # Number of epochs to wait after last improvement
best_val_loss = float('inf')  # Initialize best validation loss as infinity
epochs_no_improve = 0  # Counter for epochs without improvement

# Loop over subsets and train the model
for size, subset in dataset_subsets.items():
    print(f"\nTraining on subset size: {size}")

    # Reset early stopping parameters for each subset
    best_val_loss = float('inf')
    epochs_no_improve = 0

    # Split the subset into training, validation, and test datasets
    train_size = int(0.70 * len(subset))
    val_size = int(0.15 * len(subset))
    test_size = len(subset) - train_size - val_size
    train_dataset, val_dataset, test_dataset = random_split(subset, [train_size, val_size, test_size])

    # DataLoader setup
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Model, loss function, and optimizer setup
    model = UNet(n_class=3).to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        for batch_idx, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            labels = labels.squeeze(1).long()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item()}")

        # Validation phase
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                labels = labels.squeeze(1).long()
                loss = criterion(outputs, labels)
                val_loss += loss.item()
            val_loss /= len(val_loader)
            print(f"Validation Loss after Epoch {epoch+1}: {val_loss}")

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f"Validation Loss after Epoch {epoch+1}: {val_loss}, Epochs without improvement: {epochs_no_improve}")

        if epochs_no_improve == patience:
            print("Early stopping triggered")
            break


    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        test_loss = 0
        correct = 0
        total = 0
        dice_scores = []

        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probabilities = F.softmax(outputs, dim=1)
            _, predicted = torch.max(probabilities, 1)
            labels = labels.squeeze(1).long()

            loss = criterion(outputs, labels)
            test_loss += loss.item()
            total += labels.numel()
            correct += (predicted == labels).sum().item()

            dice_score = dice_coefficient(predicted, labels, num_classes=3)
            dice_scores.append(dice_score)

        test_loss /= len(test_loader)
        test_accuracy = 100 * correct / total
        average_dice_score = sum(dice_scores) / len(dice_scores)

        print(f"Subset size {size} - Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%, Average Dice Score: {average_dice_score:.4f}")

        # Select a few images (e.g., first 4)
        selected_images = images[:4].cpu()
        actual_labels = labels[:4].cpu()
        predicted_labels = predicted[:4].cpu()

        # Call the function
        plot_predictions(selected_images, actual_labels, predicted_labels)
# Out:
# Using cuda
#
# Training on subset size: 100
# Epoch 1/250, Batch 1/3, Loss: 1.1932106018066406
# Validation Loss after Epoch 1: 1.1083320379257202
# Validation Loss after Epoch 1: 1.1083320379257202, Epochs without improvement: 0
# Epoch 2/250, Batch 1/3, Loss: 0.36840376257896423
# Validation Loss after Epoch 2: 1.0801541805267334
# Validation Loss after Epoch 2: 1.0801541805267334, Epochs without improvement: 0
# Epoch 3/250, Batch 1/3, Loss: 0.27994054555892944
# Validation Loss after Epoch 3: 1.0009238719940186
# Validation Loss after Epoch 3: 1.0009238719940186, Epochs without improvement: 0
# Epoch 4/250, Batch 1/3, Loss: 0.2408934384584427
# Validation Loss after Epoch 4: 1.0269582271575928
# Validation Loss after Epoch 4: 1.0269582271575928, Epochs without improvement: 1
# Epoch 5/250, Batch 1/3, Loss: 0.21330241858959198
# Validation Loss after Epoch 5: 1.0679638385772705
# Validation Loss after Epoch 5: 1.0679638385772705, Epochs without improvement: 2
# Epoch 6/250, Batch 1/3, Loss: 0.18724799156188965
# Validation Loss after Epoch 6: 1.0783699750900269
# Validation Loss after Epoch 6: 1.0783699750900269, Epochs without improvement: 3
# Epoch 7/250, Batch 1/3, Loss: 0.17174522578716278
# Validation Loss after Epoch 7: 1.2517352104187012
# Validation Loss after Epoch 7: 1.2517352104187012, Epochs without improvement: 4
# Epoch 8/250, Batch 1/3, Loss: 0.15390703082084656
# Validation Loss after Epoch 8: 1.2164674997329712
# Validation Loss after Epoch 8: 1.2164674997329712, Epochs without improvement: 5
# Epoch 9/250, Batch 1/3, Loss: 0.14150390028953552
# Validation Loss after Epoch 9: 1.4958693981170654
# Validation Loss after Epoch 9: 1.4958693981170654, Epochs without improvement: 6
# Epoch 10/250, Batch 1/3, Loss: 0.12821027636528015
# Validation Loss after Epoch 10: 1.3823051452636719
# Validation Loss after Epoch 10: 1.3823051452636719, Epochs without improvement: 7
# Epoch 11/250, Batch 1/3, Loss: 0.12009247392416
# Validation Loss after Epoch 11: 1.520478367805481
# Validation Loss after Epoch 11: 1.520478367805481, Epochs without improvement: 8
# Epoch 12/250, Batch 1/3, Loss: 0.11208725720643997
# Validation Loss after Epoch 12: 1.4568371772766113
# Validation Loss after Epoch 12: 1.4568371772766113, Epochs without improvement: 9
# Epoch 13/250, Batch 1/3, Loss: 0.10596303641796112
# Validation Loss after Epoch 13: 1.36167311668396
# Validation Loss after Epoch 13: 1.36167311668396, Epochs without improvement: 10
# Early stopping triggered
# Subset size 100 - Test Loss: 1.3674, Test Accuracy: 62.40%, Average Dice Score: 0.4915
# Training on subset size: 250
# Epoch 1/250, Batch 1/6, Loss: 1.1705669164657593
# Validation Loss after Epoch 1: 1.0505708456039429
# Validation Loss after Epoch 1: 1.0505708456039429, Epochs without improvement: 0
# Epoch 2/250, Batch 1/6, Loss: 0.27234703302383423
# Validation Loss after Epoch 2: 1.0393784046173096
# Validation Loss after Epoch 2: 1.0393784046173096, Epochs without improvement: 0
# Epoch 3/250, Batch 1/6, Loss: 0.2068157196044922
# Validation Loss after Epoch 3: 1.1069400310516357
# Validation Loss after Epoch 3: 1.1069400310516357, Epochs without improvement: 1
# Epoch 4/250, Batch 1/6, Loss: 0.16705533862113953
# Validation Loss after Epoch 4: 1.2120413184165955
# Validation Loss after Epoch 4: 1.2120413184165955, Epochs without improvement: 2
# Epoch 5/250, Batch 1/6, Loss: 0.14083176851272583
# Validation Loss after Epoch 5: 1.366233229637146
# Validation Loss after Epoch 5: 1.366233229637146, Epochs without improvement: 3
# Epoch 6/250, Batch 1/6, Loss: 0.11986225843429565
# Validation Loss after Epoch 6: 1.274717390537262
# Validation Loss after Epoch 6: 1.274717390537262, Epochs without improvement: 4
# Epoch 7/250, Batch 1/6, Loss: 0.10650008171796799
# Validation Loss after Epoch 7: 1.2576059103012085
# Validation Loss after Epoch 7: 1.2576059103012085, Epochs without improvement: 5
# Epoch 8/250, Batch 1/6, Loss: 0.09522576630115509
# Validation Loss after Epoch 8: 1.1780287623405457
# Validation Loss after Epoch 8: 1.1780287623405457, Epochs without improvement: 6
# Epoch 9/250, Batch 1/6, Loss: 0.08496095985174179
# Validation Loss after Epoch 9: 0.7060627341270447
# Validation Loss after Epoch 9: 0.7060627341270447, Epochs without improvement: 0
# Epoch 10/250, Batch 1/6, Loss: 0.0798039436340332
# Validation Loss after Epoch 10: 0.28517676889896393
# Validation Loss after Epoch 10: 0.28517676889896393, Epochs without improvement: 0
# Epoch 11/250, Batch 1/6, Loss: 0.07767117023468018
# Validation Loss after Epoch 11: 0.12299201264977455
# Validation Loss after Epoch 11: 0.12299201264977455, Epochs without improvement: 0
# Epoch 12/250, Batch 1/6, Loss: 0.07084999978542328
# Validation Loss after Epoch 12: 0.07493606954813004
# Validation Loss after Epoch 12: 0.07493606954813004, Epochs without improvement: 0
# Epoch 13/250, Batch 1/6, Loss: 0.0680120661854744
# Validation Loss after Epoch 13: 0.07092829793691635
# Validation Loss after Epoch 13: 0.07092829793691635, Epochs without improvement: 0
# Epoch 14/250, Batch 1/6, Loss: 0.06316462904214859
# Validation Loss after Epoch 14: 0.05811699479818344
# Validation Loss after Epoch 14: 0.05811699479818344, Epochs without improvement: 0
# Epoch 15/250, Batch 1/6, Loss: 0.061536841094493866
# Validation Loss after Epoch 15: 0.05398428626358509
# Validation Loss after Epoch 15: 0.05398428626358509, Epochs without improvement: 0
# Epoch 16/250, Batch 1/6, Loss: 0.058308858424425125
# Validation Loss after Epoch 16: 0.05402865447103977
# Validation Loss after Epoch 16: 0.05402865447103977, Epochs without improvement: 1
# Epoch 17/250, Batch 1/6, Loss: 0.05811623856425285
# Validation Loss after Epoch 17: 0.05205152742564678
# Validation Loss after Epoch 17: 0.05205152742564678, Epochs without improvement: 0
# Epoch 18/250, Batch 1/6, Loss: 0.05405633524060249
# Validation Loss after Epoch 18: 0.048295145854353905
# Validation Loss after Epoch 18: 0.048295145854353905, Epochs without improvement: 0
# Epoch 19/250, Batch 1/6, Loss: 0.05222192034125328
# Validation Loss after Epoch 19: 0.0460425429046154
# Validation Loss after Epoch 19: 0.0460425429046154, Epochs without improvement: 0
# Epoch 20/250, Batch 1/6, Loss: 0.04948406666517258
# Validation Loss after Epoch 20: 0.045904407277703285
# Validation Loss after Epoch 20: 0.045904407277703285, Epochs without improvement: 0
# Epoch 21/250, Batch 1/6, Loss: 0.04921720176935196
# Validation Loss after Epoch 21: 0.0441190991550684
# Validation Loss after Epoch 21: 0.0441190991550684, Epochs without improvement: 0
# Epoch 22/250, Batch 1/6, Loss: 0.04566962644457817
# Validation Loss after Epoch 22: 0.04318603128194809
# Validation Loss after Epoch 22: 0.04318603128194809, Epochs without improvement: 0
# Epoch 23/250, Batch 1/6, Loss: 0.04523635655641556
# Validation Loss after Epoch 23: 0.04358033277094364
# Validation Loss after Epoch 23: 0.04358033277094364, Epochs without improvement: 1
# Epoch 24/250, Batch 1/6, Loss: 0.04484354704618454
# Validation Loss after Epoch 24: 0.04157370515167713
# Validation Loss after Epoch 24: 0.04157370515167713, Epochs without improvement: 0
# Epoch 25/250, Batch 1/6, Loss: 0.04237250238656998
# Validation Loss after Epoch 25: 0.04122418910264969
# Validation Loss after Epoch 25: 0.04122418910264969, Epochs without improvement: 0
# Epoch 26/250, Batch 1/6, Loss: 0.04160783812403679
# Validation Loss after Epoch 26: 0.04090980999171734
# Validation Loss after Epoch 26: 0.04090980999171734, Epochs without improvement: 0
# Epoch 27/250, Batch 1/6, Loss: 0.039201147854328156
# Validation Loss after Epoch 27: 0.03899319842457771
# Validation Loss after Epoch 27: 0.03899319842457771, Epochs without improvement: 0
# Epoch 28/250, Batch 1/6, Loss: 0.03977668657898903
# Validation Loss after Epoch 28: 0.036638617515563965
# Validation Loss after Epoch 28: 0.036638617515563965, Epochs without improvement: 0
# Epoch 29/250, Batch 1/6, Loss: 0.038165029138326645
# Validation Loss after Epoch 29: 0.03939530812203884
# Validation Loss after Epoch 29: 0.03939530812203884, Epochs without improvement: 1
# Epoch 30/250, Batch 1/6, Loss: 0.03646763414144516
# Validation Loss after Epoch 30: 0.03714118339121342
# Validation Loss after Epoch 30: 0.03714118339121342, Epochs without improvement: 2
# Epoch 31/250, Batch 1/6, Loss: 0.03637798875570297
# Validation Loss after Epoch 31: 0.03611129894852638
# Validation Loss after Epoch 31: 0.03611129894852638, Epochs without improvement: 0
# Epoch 32/250, Batch 1/6, Loss: 0.034370627254247665
# Validation Loss after Epoch 32: 0.04032719321548939
# Validation Loss after Epoch 32: 0.04032719321548939, Epochs without improvement: 1
# Epoch 33/250, Batch 1/6, Loss: 0.03379441425204277
# Validation Loss after Epoch 33: 0.03525638394057751
# Validation Loss after Epoch 33: 0.03525638394057751, Epochs without improvement: 0
# Epoch 34/250, Batch 1/6, Loss: 0.03292396292090416
# Validation Loss after Epoch 34: 0.035927789285779
# Validation Loss after Epoch 34: 0.035927789285779, Epochs without improvement: 1
# Epoch 35/250, Batch 1/6, Loss: 0.0316101498901844
# Validation Loss after Epoch 35: 0.03434729017317295
# Validation Loss after Epoch 35: 0.03434729017317295, Epochs without improvement: 0
# Epoch 36/250, Batch 1/6, Loss: 0.031930163502693176
# Validation Loss after Epoch 36: 0.03262627683579922
# Validation Loss after Epoch 36: 0.03262627683579922, Epochs without improvement: 0
# Epoch 37/250, Batch 1/6, Loss: 0.030675813555717468
# Validation Loss after Epoch 37: 0.034698380157351494
# Validation Loss after Epoch 37: 0.034698380157351494, Epochs without improvement: 1
# Epoch 38/250, Batch 1/6, Loss: 0.030780255794525146
# Validation Loss after Epoch 38: 0.035448988899588585
# Validation Loss after Epoch 38: 0.035448988899588585, Epochs without improvement: 2
# Epoch 39/250, Batch 1/6, Loss: 0.029110495001077652
# Validation Loss after Epoch 39: 0.03415888361632824
# Validation Loss after Epoch 39: 0.03415888361632824, Epochs without improvement: 3
# Epoch 40/250, Batch 1/6, Loss: 0.02933630160987377
# Validation Loss after Epoch 40: 0.03426519222557545
# Validation Loss after Epoch 40: 0.03426519222557545, Epochs without improvement: 4
# Epoch 41/250, Batch 1/6, Loss: 0.02996120974421501
# Validation Loss after Epoch 41: 0.03405730798840523
# Validation Loss after Epoch 41: 0.03405730798840523, Epochs without improvement: 5
# Epoch 42/250, Batch 1/6, Loss: 0.028071053326129913
# Validation Loss after Epoch 42: 0.03658461757004261
# Validation Loss after Epoch 42: 0.03658461757004261, Epochs without improvement: 6
# Epoch 43/250, Batch 1/6, Loss: 0.028623061254620552
# Validation Loss after Epoch 43: 0.033200884237885475
# Validation Loss after Epoch 43: 0.033200884237885475, Epochs without improvement: 7
# Epoch 44/250, Batch 1/6, Loss: 0.026152215898036957
# Validation Loss after Epoch 44: 0.03316218964755535
# Validation Loss after Epoch 44: 0.03316218964755535, Epochs without improvement: 8
# Epoch 45/250, Batch 1/6, Loss: 0.025369515642523766
# Validation Loss after Epoch 45: 0.03230664134025574
# Validation Loss after Epoch 45: 0.03230664134025574, Epochs without improvement: 0
# Epoch 46/250, Batch 1/6, Loss: 0.026041332632303238
# Validation Loss after Epoch 46: 0.032689088955521584
# Validation Loss after Epoch 46: 0.032689088955521584, Epochs without improvement: 1
# Epoch 47/250, Batch 1/6, Loss: 0.025571279227733612
# Validation Loss after Epoch 47: 0.03160020895302296
# Validation Loss after Epoch 47: 0.03160020895302296, Epochs without improvement: 0
# Epoch 48/250, Batch 1/6, Loss: 0.025546077638864517
# Validation Loss after Epoch 48: 0.03170367330312729
# Validation Loss after Epoch 48: 0.03170367330312729, Epochs without improvement: 1
# Epoch 49/250, Batch 1/6, Loss: 0.023468807339668274
# Validation Loss after Epoch 49: 0.03212488815188408
# Validation Loss after Epoch 49: 0.03212488815188408, Epochs without improvement: 2
# Epoch 50/250, Batch 1/6, Loss: 0.022474322468042374
# Validation Loss after Epoch 50: 0.030585000291466713
# Validation Loss after Epoch 50: 0.030585000291466713, Epochs without improvement: 0
# Epoch 51/250, Batch 1/6, Loss: 0.023672033101320267
# Validation Loss after Epoch 51: 0.030583092011511326
# Validation Loss after Epoch 51: 0.030583092011511326, Epochs without improvement: 0
# Epoch 52/250, Batch 1/6, Loss: 0.02346903458237648
# Validation Loss after Epoch 52: 0.031548021361231804
# Validation Loss after Epoch 52: 0.031548021361231804, Epochs without improvement: 1
# Epoch 53/250, Batch 1/6, Loss: 0.02280665934085846
# Validation Loss after Epoch 53: 0.03203367255628109
# Validation Loss after Epoch 53: 0.03203367255628109, Epochs without improvement: 2
# Epoch 54/250, Batch 1/6, Loss: 0.021692199632525444
# Validation Loss after Epoch 54: 0.03078287560492754
# Validation Loss after Epoch 54: 0.03078287560492754, Epochs without improvement: 3
# Epoch 55/250, Batch 1/6, Loss: 0.02161874994635582
# Validation Loss after Epoch 55: 0.03366157039999962
# Validation Loss after Epoch 55: 0.03366157039999962, Epochs without improvement: 4
# Epoch 56/250, Batch 1/6, Loss: 0.021730082109570503
# Validation Loss after Epoch 56: 0.034875331446528435
# Validation Loss after Epoch 56: 0.034875331446528435, Epochs without improvement: 5
# Epoch 57/250, Batch 1/6, Loss: 0.021894395351409912
# Validation Loss after Epoch 57: 0.031571670435369015
# Validation Loss after Epoch 57: 0.031571670435369015, Epochs without improvement: 6
# Epoch 58/250, Batch 1/6, Loss: 0.021625449880957603
# Validation Loss after Epoch 58: 0.032839737832546234
# Validation Loss after Epoch 58: 0.032839737832546234, Epochs without improvement: 7
# Epoch 59/250, Batch 1/6, Loss: 0.01980334334075451
# Validation Loss after Epoch 59: 0.037046583369374275
# Validation Loss after Epoch 59: 0.037046583369374275, Epochs without improvement: 8
# Epoch 60/250, Batch 1/6, Loss: 0.020145269110798836
# Validation Loss after Epoch 60: 0.03273831494152546
# Validation Loss after Epoch 60: 0.03273831494152546, Epochs without improvement: 9
# Epoch 61/250, Batch 1/6, Loss: 0.019119655713438988
# Validation Loss after Epoch 61: 0.031018933281302452
# Validation Loss after Epoch 61: 0.031018933281302452, Epochs without improvement: 10
# Early stopping triggered
# Subset size 250 - Test Loss: 0.0300, Test Accuracy: 98.82%, Average Dice Score: 0.9880
# Training on subset size: 500
# Epoch 1/250, Batch 1/11, Loss: 1.1867165565490723
# Epoch 1/250, Batch 11/11, Loss: 0.23669548332691193
# Validation Loss after Epoch 1: 1.1349167426427205
# Validation Loss after Epoch 1: 1.1349167426427205, Epochs without improvement: 0
# Epoch 2/250, Batch 1/11, Loss: 0.22519917786121368
# Epoch 2/250, Batch 11/11, Loss: 0.15727585554122925
# Validation Loss after Epoch 2: 1.198559006055196
# Validation Loss after Epoch 2: 1.198559006055196, Epochs without improvement: 1
# Epoch 3/250, Batch 1/11, Loss: 0.1539449691772461
# Epoch 3/250, Batch 11/11, Loss: 0.11732682585716248
# Validation Loss after Epoch 3: 1.488635818163554
# Validation Loss after Epoch 3: 1.488635818163554, Epochs without improvement: 2
# Epoch 4/250, Batch 1/11, Loss: 0.11472976207733154
# Epoch 4/250, Batch 11/11, Loss: 0.0962548702955246
# Validation Loss after Epoch 4: 1.3531176646550496
# Validation Loss after Epoch 4: 1.3531176646550496, Epochs without improvement: 3
# Epoch 5/250, Batch 1/11, Loss: 0.09330965578556061
# Epoch 5/250, Batch 11/11, Loss: 0.08173731714487076
# Validation Loss after Epoch 5: 0.6625048120816549
# Validation Loss after Epoch 5: 0.6625048120816549, Epochs without improvement: 0
# Epoch 6/250, Batch 1/11, Loss: 0.07868092507123947
# Epoch 6/250, Batch 11/11, Loss: 0.07388574630022049
# Validation Loss after Epoch 6: 0.20385324458281198
# Validation Loss after Epoch 6: 0.20385324458281198, Epochs without improvement: 0
# Epoch 7/250, Batch 1/11, Loss: 0.07066133618354797
# Epoch 7/250, Batch 11/11, Loss: 0.0658300444483757
# Validation Loss after Epoch 7: 0.09322968125343323
# Validation Loss after Epoch 7: 0.09322968125343323, Epochs without improvement: 0
# Epoch 8/250, Batch 1/11, Loss: 0.0660587027668953
# Epoch 8/250, Batch 11/11, Loss: 0.06063418090343475
# Validation Loss after Epoch 8: 0.062240276485681534
# Validation Loss after Epoch 8: 0.062240276485681534, Epochs without improvement: 0
# Epoch 9/250, Batch 1/11, Loss: 0.060544706881046295
# Epoch 9/250, Batch 11/11, Loss: 0.05673332139849663
# Validation Loss after Epoch 9: 0.05286626021067301
# Validation Loss after Epoch 9: 0.05286626021067301, Epochs without improvement: 0
# Epoch 10/250, Batch 1/11, Loss: 0.0549176000058651
# Epoch 10/250, Batch 11/11, Loss: 0.05157511681318283
# Validation Loss after Epoch 10: 0.04835993051528931
# Validation Loss after Epoch 10: 0.04835993051528931, Epochs without improvement: 0
# Epoch 11/250, Batch 1/11, Loss: 0.0506850890815258
# Epoch 11/250, Batch 11/11, Loss: 0.048848073929548264
# Validation Loss after Epoch 11: 0.04566008597612381
# Validation Loss after Epoch 11: 0.04566008597612381, Epochs without improvement: 0
# Epoch 12/250, Batch 1/11, Loss: 0.048356927931308746
# Epoch 12/250, Batch 11/11, Loss: 0.0459127239882946
# Validation Loss after Epoch 12: 0.04715877895553907
# Validation Loss after Epoch 12: 0.04715877895553907, Epochs without improvement: 1
# Epoch 13/250, Batch 1/11, Loss: 0.04703674837946892
# Epoch 13/250, Batch 11/11, Loss: 0.0444055050611496
# Validation Loss after Epoch 13: 0.0418148065606753
# Validation Loss after Epoch 13: 0.0418148065606753, Epochs without improvement: 0
# Epoch 14/250, Batch 1/11, Loss: 0.04400690272450447
# Epoch 14/250, Batch 11/11, Loss: 0.04222291335463524
# Validation Loss after Epoch 14: 0.04225551957885424
# Validation Loss after Epoch 14: 0.04225551957885424, Epochs without improvement: 1
# Epoch 15/250, Batch 1/11, Loss: 0.040493469685316086
# Epoch 15/250, Batch 11/11, Loss: 0.039367612451314926
# Validation Loss after Epoch 15: 0.04245088994503021
# Validation Loss after Epoch 15: 0.04245088994503021, Epochs without improvement: 2
# Epoch 16/250, Batch 1/11, Loss: 0.039801329374313354
# Epoch 16/250, Batch 11/11, Loss: 0.03775060549378395
# Validation Loss after Epoch 16: 0.035855982452631
# Validation Loss after Epoch 16: 0.035855982452631, Epochs without improvement: 0
# Epoch 17/250, Batch 1/11, Loss: 0.03750862181186676
# Epoch 17/250, Batch 11/11, Loss: 0.03687397018074989
# Validation Loss after Epoch 17: 0.03783580784996351
# Validation Loss after Epoch 17: 0.03783580784996351, Epochs without improvement: 1
# Epoch 18/250, Batch 1/11, Loss: 0.03661279380321503
# Epoch 18/250, Batch 11/11, Loss: 0.035017792135477066
# Validation Loss after Epoch 18: 0.03783444811900457
# Validation Loss after Epoch 18: 0.03783444811900457, Epochs without improvement: 2
# Epoch 19/250, Batch 1/11, Loss: 0.034738823771476746
# Epoch 19/250, Batch 11/11, Loss: 0.03501216694712639
# Validation Loss after Epoch 19: 0.03964336961507797
# Validation Loss after Epoch 19: 0.03964336961507797, Epochs without improvement: 3
# Epoch 20/250, Batch 1/11, Loss: 0.036524344235658646
# Epoch 20/250, Batch 11/11, Loss: 0.03441180661320686
# Validation Loss after Epoch 20: 0.032780529310305916
# Validation Loss after Epoch 20: 0.032780529310305916, Epochs without improvement: 0
# Epoch 21/250, Batch 1/11, Loss: 0.03317057341337204
# Epoch 21/250, Batch 11/11, Loss: 0.03249447047710419
# Validation Loss after Epoch 21: 0.03279375284910202
# Validation Loss after Epoch 21: 0.03279375284910202, Epochs without improvement: 1
# Epoch 22/250, Batch 1/11, Loss: 0.03219716623425484
# Epoch 22/250, Batch 11/11, Loss: 0.0313555970788002
# Validation Loss after Epoch 22: 0.03024624225993951
# Validation Loss after Epoch 22: 0.03024624225993951, Epochs without improvement: 0
# Epoch 23/250, Batch 1/11, Loss: 0.03074072301387787
# Epoch 23/250, Batch 11/11, Loss: 0.031076675280928612
# Validation Loss after Epoch 23: 0.03275327757000923
# Validation Loss after Epoch 23: 0.03275327757000923, Epochs without improvement: 1
# Epoch 24/250, Batch 1/11, Loss: 0.030025456100702286
# Epoch 24/250, Batch 11/11, Loss: 0.03228115290403366
# Validation Loss after Epoch 24: 0.0344520037372907
# Validation Loss after Epoch 24: 0.0344520037372907, Epochs without improvement: 2
# Epoch 25/250, Batch 1/11, Loss: 0.03049234114587307
# Epoch 25/250, Batch 11/11, Loss: 0.030132539570331573
# Validation Loss after Epoch 25: 0.030017888794342678
# Validation Loss after Epoch 25: 0.030017888794342678, Epochs without improvement: 0
# Epoch 26/250, Batch 1/11, Loss: 0.027898499742150307
# Epoch 26/250, Batch 11/11, Loss: 0.028429845348000526
# Validation Loss after Epoch 26: 0.028441589946548145
# Validation Loss after Epoch 26: 0.028441589946548145, Epochs without improvement: 0
# Epoch 27/250, Batch 1/11, Loss: 0.02829846926033497
# Epoch 27/250, Batch 11/11, Loss: 0.02928268536925316
# Validation Loss after Epoch 27: 0.029060666759808857
# Validation Loss after Epoch 27: 0.029060666759808857, Epochs without improvement: 1
# Epoch 28/250, Batch 1/11, Loss: 0.026945708319544792
# Epoch 28/250, Batch 11/11, Loss: 0.027279550209641457
# Validation Loss after Epoch 28: 0.02787543584903081
# Validation Loss after Epoch 28: 0.02787543584903081, Epochs without improvement: 0
# Epoch 29/250, Batch 1/11, Loss: 0.02664978615939617
# Epoch 29/250, Batch 11/11, Loss: 0.026647137477993965
# Validation Loss after Epoch 29: 0.0272176389892896
# Validation Loss after Epoch 29: 0.0272176389892896, Epochs without improvement: 0
# Epoch 30/250, Batch 1/11, Loss: 0.025170324370265007
# Epoch 30/250, Batch 11/11, Loss: 0.028134195134043694
# Validation Loss after Epoch 30: 0.026584461331367493
# Validation Loss after Epoch 30: 0.026584461331367493, Epochs without improvement: 0
# Epoch 31/250, Batch 1/11, Loss: 0.025459710508584976
# Epoch 31/250, Batch 11/11, Loss: 0.025974135845899582
# Validation Loss after Epoch 31: 0.02721011886994044
# Validation Loss after Epoch 31: 0.02721011886994044, Epochs without improvement: 1
# Epoch 32/250, Batch 1/11, Loss: 0.02443827874958515
# Epoch 32/250, Batch 11/11, Loss: 0.024653112515807152
# Validation Loss after Epoch 32: 0.026643309742212296
# Validation Loss after Epoch 32: 0.026643309742212296, Epochs without improvement: 2
# Epoch 33/250, Batch 1/11, Loss: 0.023684464395046234
# Epoch 33/250, Batch 11/11, Loss: 0.0242779441177845
# Validation Loss after Epoch 33: 0.026355774452288944
# Validation Loss after Epoch 33: 0.026355774452288944, Epochs without improvement: 0
# Epoch 34/250, Batch 1/11, Loss: 0.024242037907242775
# Epoch 34/250, Batch 11/11, Loss: 0.02387886680662632
# Validation Loss after Epoch 34: 0.028343230485916138
# Validation Loss after Epoch 34: 0.028343230485916138, Epochs without improvement: 1
# Epoch 35/250, Batch 1/11, Loss: 0.02305513061583042
# Epoch 35/250, Batch 11/11, Loss: 0.023940645158290863
# Validation Loss after Epoch 35: 0.02497896800438563
# Validation Loss after Epoch 35: 0.02497896800438563, Epochs without improvement: 0
# Epoch 36/250, Batch 1/11, Loss: 0.02263781987130642
# Epoch 36/250, Batch 11/11, Loss: 0.022602815181016922
# Validation Loss after Epoch 36: 0.026084570835034054
# Validation Loss after Epoch 36: 0.026084570835034054, Epochs without improvement: 1
# Epoch 37/250, Batch 1/11, Loss: 0.0222097747027874
# Epoch 37/250, Batch 11/11, Loss: 0.022803299129009247
# Validation Loss after Epoch 37: 0.025491373613476753
# Validation Loss after Epoch 37: 0.025491373613476753, Epochs without improvement: 2
# Epoch 38/250, Batch 1/11, Loss: 0.02121516317129135
# Epoch 38/250, Batch 11/11, Loss: 0.024362344294786453
# Validation Loss after Epoch 38: 0.029285027955969174
# Validation Loss after Epoch 38: 0.029285027955969174, Epochs without improvement: 3
# Epoch 39/250, Batch 1/11, Loss: 0.02118160016834736
# Epoch 39/250, Batch 11/11, Loss: 0.021804222837090492
# Validation Loss after Epoch 39: 0.025075512006878853
# Validation Loss after Epoch 39: 0.025075512006878853, Epochs without improvement: 4
# Epoch 40/250, Batch 1/11, Loss: 0.020420415326952934
# Epoch 40/250, Batch 11/11, Loss: 0.021724555641412735
# Validation Loss after Epoch 40: 0.02566369374593099
# Validation Loss after Epoch 40: 0.02566369374593099, Epochs without improvement: 5
# Epoch 41/250, Batch 1/11, Loss: 0.02273535169661045
# Epoch 41/250, Batch 11/11, Loss: 0.020842911675572395
# Validation Loss after Epoch 41: 0.02924521639943123
# Validation Loss after Epoch 41: 0.02924521639943123, Epochs without improvement: 6
# Epoch 42/250, Batch 1/11, Loss: 0.023714600130915642
# Epoch 42/250, Batch 11/11, Loss: 0.021454472094774246
# Validation Loss after Epoch 42: 0.024687185883522034
# Validation Loss after Epoch 42: 0.024687185883522034, Epochs without improvement: 0
# Epoch 43/250, Batch 1/11, Loss: 0.01956084556877613
# Epoch 43/250, Batch 11/11, Loss: 0.02088760957121849
# Validation Loss after Epoch 43: 0.024963550890485447
# Validation Loss after Epoch 43: 0.024963550890485447, Epochs without improvement: 1
# Epoch 44/250, Batch 1/11, Loss: 0.01892346329987049
# Epoch 44/250, Batch 11/11, Loss: 0.02088337019085884
# Validation Loss after Epoch 44: 0.024123789742588997
# Validation Loss after Epoch 44: 0.024123789742588997, Epochs without improvement: 0
# Epoch 45/250, Batch 1/11, Loss: 0.018809659406542778
# Epoch 45/250, Batch 11/11, Loss: 0.019886987283825874
# Validation Loss after Epoch 45: 0.024533559878667194
# Validation Loss after Epoch 45: 0.024533559878667194, Epochs without improvement: 1
# Epoch 46/250, Batch 1/11, Loss: 0.018243251368403435
# Epoch 46/250, Batch 11/11, Loss: 0.019385037943720818
# Validation Loss after Epoch 46: 0.028529567644000053
# Validation Loss after Epoch 46: 0.028529567644000053, Epochs without improvement: 2
# Epoch 47/250, Batch 1/11, Loss: 0.018405059352517128
# Epoch 47/250, Batch 11/11, Loss: 0.020150428637862206
# Validation Loss after Epoch 47: 0.026133129994074505
# Validation Loss after Epoch 47: 0.026133129994074505, Epochs without improvement: 3
# Epoch 48/250, Batch 1/11, Loss: 0.018216054886579514
# Epoch 48/250, Batch 11/11, Loss: 0.018530426546931267
# Validation Loss after Epoch 48: 0.024013978739579517
# Validation Loss after Epoch 48: 0.024013978739579517, Epochs without improvement: 0
# Epoch 49/250, Batch 1/11, Loss: 0.01779882423579693
# Epoch 49/250, Batch 11/11, Loss: 0.018512040376663208
# Validation Loss after Epoch 49: 0.025651537502805393
# Validation Loss after Epoch 49: 0.025651537502805393, Epochs without improvement: 1
# Epoch 50/250, Batch 1/11, Loss: 0.017392277717590332
# Epoch 50/250, Batch 11/11, Loss: 0.017549222335219383
# Validation Loss after Epoch 50: 0.02444767455259959
# Validation Loss after Epoch 50: 0.02444767455259959, Epochs without improvement: 2
# Epoch 51/250, Batch 1/11, Loss: 0.0165021400898695
# Epoch 51/250, Batch 11/11, Loss: 0.02097032405436039
# Validation Loss after Epoch 51: 0.024502602095405262
# Validation Loss after Epoch 51: 0.024502602095405262, Epochs without improvement: 3
# Epoch 52/250, Batch 1/11, Loss: 0.01621054671704769
# Epoch 52/250, Batch 11/11, Loss: 0.018055293709039688
# Validation Loss after Epoch 52: 0.025209644188483555
# Validation Loss after Epoch 52: 0.025209644188483555, Epochs without improvement: 4
# Epoch 53/250, Batch 1/11, Loss: 0.018597695976495743
# Epoch 53/250, Batch 11/11, Loss: 0.017419615760445595
# Validation Loss after Epoch 53: 0.026708524053295452
# Validation Loss after Epoch 53: 0.026708524053295452, Epochs without improvement: 5
# Epoch 54/250, Batch 1/11, Loss: 0.016059082001447678
# Epoch 54/250, Batch 11/11, Loss: 0.017165401950478554
# Validation Loss after Epoch 54: 0.024792127311229706
# Validation Loss after Epoch 54: 0.024792127311229706, Epochs without improvement: 6
# Epoch 55/250, Batch 1/11, Loss: 0.01633720099925995
# Epoch 55/250, Batch 11/11, Loss: 0.01618480496108532
# Validation Loss after Epoch 55: 0.02486576947073142
# Validation Loss after Epoch 55: 0.02486576947073142, Epochs without improvement: 7
# Epoch 56/250, Batch 1/11, Loss: 0.015244199894368649
# Epoch 56/250, Batch 11/11, Loss: 0.017156308516860008
# Validation Loss after Epoch 56: 0.024978577469786007
# Validation Loss after Epoch 56: 0.024978577469786007, Epochs without improvement: 8
# Epoch 57/250, Batch 1/11, Loss: 0.014960945583879948
# Epoch 57/250, Batch 11/11, Loss: 0.015582961961627007
# Validation Loss after Epoch 57: 0.025481533259153366
# Validation Loss after Epoch 57: 0.025481533259153366, Epochs without improvement: 9
# Epoch 58/250, Batch 1/11, Loss: 0.014870517887175083
# Epoch 58/250, Batch 11/11, Loss: 0.015772607177495956
# Validation Loss after Epoch 58: 0.025561098630229633
# Validation Loss after Epoch 58: 0.025561098630229633, Epochs without improvement: 10
# Early stopping triggered
# Subset size 500 - Test Loss: 0.0261, Test Accuracy: 98.97%, Average Dice Score: 0.9896

# %%
torch.save(model.state_dict(), '128x128smaller_subsets_with_Early_Stoppage.pth')
